# %%
#import lib
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import getpass # to hide the password
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Instructions
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
client_id = getpass.getpass('id?')
client_secret = getpass.getpass('secret?')
# Out:
# id?········
# secret?········

# %%
# we create and store a connection to the api
sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id = client_id
                                                            , client_secret = client_secret))

# %%
# from this list of artist we are going to extract the top 50 sogns in spotify and extract ids and audio features
artists = ["Mango", "Madonna","Mercedes Sosa","Nirvana", "Pavarotti", "Queen", "Metallica"
          ,"Jovanotti", "Zucchero", "Neffa", "Quantic", "Afterhours", "Verdena", "Kyuss",
           "Tame Impala", "Roxette", "Juanes", "Carla Morrison", "Barbara Bonney", "Charly Garcia", "La Portuaria", "Intoxicados",
           "Uncle Acid & The Deadbeats", "Raly Barrionuevo", "Richard Bona", "Greg Howe", "George Benson", "Bill Evans", "Divididos", "Jimi Hendrix", "Ratones Paranoicos", "James Rhodes", "The Doors", "Keith Richards",
           "Elder","Colour Haze",
           "Electric Wizard",
           "Witch",
           "Electric Octopus",
           "All Them Witches",
           "Dead Meadow",
           "OM",
           "Red Fang",
           "Sleep",
           "The Sword",
           "Fu Manchu",
           "Kadavar",
           "Witchcraft",
           "Pentagram",
           "Black Sabbath",
           "Orange Goblin"] 
# loop the artist search
#sp.searc pertutti gli artisti nella lista
my_20_artists = [sp.search(q= artist , limit = 50) for artist in artists]
# create the dictionary
#def artist_to_dict(artists):
   # return{artist:sp.search(q= artist , limit = 50) for artist in artists}
#len(artist_to_dict(artists))

# %%
# get artist name and ids for all the artist
# each item is a dict itself
my_20_artists[3]['tracks'].keys() #each track on spotify is a dictionary witht the following keys

# %%
my_20_artists[3]['tracks']['total'] # total reproduction
# Out:
# 48029

# %%
# Nirvana, track item number 1
# from here we can find id, uri, etc
my_20_artists[3]['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#   'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#   'id': '2guirTSEqLizK7j9i1MTTZ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#     'width': 64}],
#   'name': 'Nevermind (Remastered)',
#   'release_date': '1991-09-26',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:2guirTSEqLizK7j9i1MTTZ'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#    'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#    'id': '6olE6TJLqED3rqDCT0FyPh',
#    'name': 'Nirvana',
#    'type': 'artist',
#    'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#  'available_markets': ['CA', 'MX', 'US'],
#  'disc_number': 1,
#  'duration_ms': 301920,
#  'explicit': False,
#  'external_ids': {'isrc': 'USGF19942501'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5ghIJDpPoe3CfHMGu71E6T'},
#  'href': 'https://api.spotify.com/v1/tracks/5ghIJDpPoe3CfHMGu71E6T',
#  'id': '5ghIJDpPoe3CfHMGu71E6T',
#  'is_local': False,
#  'name': 'Smells Like Teen Spirit',
#  'popularity': 76,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:5ghIJDpPoe3CfHMGu71E6T'}

# %%
# song title
my_20_artists[3]['tracks']['items'][0]['name']
# Out:
# 'Smells Like Teen Spirit'

# %%
# my_20_artists[3]['tracks']['items']
my_20_artists[3]['tracks']['items'][0].keys()#['name']
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# I found one item and now I need to iterate to get all items for each artist
my_20_artists[3]['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#    'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#    'id': '2guirTSEqLizK7j9i1MTTZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#      'width': 64}],
#    'name': 'Nevermind (Remastered)',
#    'release_date': '1991-09-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:2guirTSEqLizK7j9i1MTTZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 301920,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19942501'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5ghIJDpPoe3CfHMGu71E6T'},
#   'href': 'https://api.spotify.com/v1/tracks/5ghIJDpPoe3CfHMGu71E6T',
#   'id': '5ghIJDpPoe3CfHMGu71E6T',
#   'is_local': False,
#   'name': 'Smells Like Teen Spirit',
#   'popularity': 76,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5ghIJDpPoe3CfHMGu71E6T'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#    'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#    'id': '2guirTSEqLizK7j9i1MTTZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#      'width': 64}],
#    'name': 'Nevermind (Remastered)',
#    'release_date': '1991-09-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:2guirTSEqLizK7j9i1MTTZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 218920,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19942503'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4P5KoWXOxwuobLmHXLMobV'},
#   'href': 'https://api.spotify.com/v1/tracks/4P5KoWXOxwuobLmHXLMobV',
#   'id': '4P5KoWXOxwuobLmHXLMobV',
#   'is_local': False,
#   'name': 'Come As You Are',
#   'popularity': 74,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:4P5KoWXOxwuobLmHXLMobV'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['AD',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KZ',
#     'LA',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PT',
#     'PW',
#     'PY',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6ohX7moZZnF1FwYrli1OJ6'},
#    'href': 'https://api.spotify.com/v1/albums/6ohX7moZZnF1FwYrli1OJ6',
#    'id': '6ohX7moZZnF1FwYrli1OJ6',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273aca059cebc1841277db22d1c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02aca059cebc1841277db22d1c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851aca059cebc1841277db22d1c',
#      'width': 64}],
#    'name': 'In Utero - 20th Anniversary - Deluxe Edition',
#    'release_date': '1993-09-21',
#    'release_date_precision': 'day',
#    'total_tracks': 43,
#    'type': 'album',
#    'uri': 'spotify:album:6ohX7moZZnF1FwYrli1OJ6'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['AD',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KZ',
#    'LA',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PT',
#    'PW',
#    'PY',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 281160,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19960703'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/11LmqTE2naFULdEP94AUBa'},
#   'href': 'https://api.spotify.com/v1/tracks/11LmqTE2naFULdEP94AUBa',
#   'id': '11LmqTE2naFULdEP94AUBa',
#   'is_local': False,
#   'name': 'Heart-Shaped Box',
#   'popularity': 76,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:11LmqTE2naFULdEP94AUBa'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t0KCCFs6BIelOxE4XGDRT'},
#      'href': 'https://api.spotify.com/v1/artists/5t0KCCFs6BIelOxE4XGDRT',
#      'id': '5t0KCCFs6BIelOxE4XGDRT',
#      'name': 'ELLIANA',
#      'type': 'artist',
#      'uri': 'spotify:artist:5t0KCCFs6BIelOxE4XGDRT'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'ZA',
#     'ZM'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6HcXFfZ41boaTaIwGa3oPh'},
#    'href': 'https://api.spotify.com/v1/albums/6HcXFfZ41boaTaIwGa3oPh',
#    'id': '6HcXFfZ41boaTaIwGa3oPh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27350ab87179db457a93f8b8cb3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0250ab87179db457a93f8b8cb3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485150ab87179db457a93f8b8cb3',
#      'width': 64}],
#    'name': 'Nirvana',
#    'release_date': '2020-04-16',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:6HcXFfZ41boaTaIwGa3oPh'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t0KCCFs6BIelOxE4XGDRT'},
#     'href': 'https://api.spotify.com/v1/artists/5t0KCCFs6BIelOxE4XGDRT',
#     'id': '5t0KCCFs6BIelOxE4XGDRT',
#     'name': 'ELLIANA',
#     'type': 'artist',
#     'uri': 'spotify:artist:5t0KCCFs6BIelOxE4XGDRT'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'ZA',
#    'ZM'],
#   'disc_number': 1,
#   'duration_ms': 266036,
#   'explicit': False,
#   'external_ids': {'isrc': 'TCAES2044567'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/11VPN6SfBRRmF2fESXlNep'},
#   'href': 'https://api.spotify.com/v1/tracks/11VPN6SfBRRmF2fESXlNep',
#   'id': '11VPN6SfBRRmF2fESXlNep',
#   'is_local': False,
#   'name': 'Nirvana',
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/f0fead201d1067533e297895690a4d402ace0b35?cid=458a20bd06e9408c95af3d0901c21965',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:11VPN6SfBRRmF2fESXlNep'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#    'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#    'id': '2guirTSEqLizK7j9i1MTTZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#      'width': 64}],
#    'name': 'Nevermind (Remastered)',
#    'release_date': '1991-09-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:2guirTSEqLizK7j9i1MTTZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 257053,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19942505'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2YodwKJnbPyNKe8XXSE9V7'},
#   'href': 'https://api.spotify.com/v1/tracks/2YodwKJnbPyNKe8XXSE9V7',
#   'id': '2YodwKJnbPyNKe8XXSE9V7',
#   'is_local': False,
#   'name': 'Lithium',
#   'popularity': 69,
#   'preview_url': None,
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:2YodwKJnbPyNKe8XXSE9V7'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#    'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#    'id': '2guirTSEqLizK7j9i1MTTZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#      'width': 64}],
#    'name': 'Nevermind (Remastered)',
#    'release_date': '1991-09-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:2guirTSEqLizK7j9i1MTTZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 255080,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19942502'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/30HCB1FoE77IfGRyNv4eFq'},
#   'href': 'https://api.spotify.com/v1/tracks/30HCB1FoE77IfGRyNv4eFq',
#   'id': '30HCB1FoE77IfGRyNv4eFq',
#   'is_local': False,
#   'name': 'In Bloom - Nevermind Version',
#   'popularity': 67,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:30HCB1FoE77IfGRyNv4eFq'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#      'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#      'id': '2wY79sveU1sp5g7SokKOiI',
#      'name': 'Sam Smith',
#      'type': 'artist',
#      'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0vrWqbRQEMKqhTGcDLQK7x'},
#    'href': 'https://api.spotify.com/v1/albums/0vrWqbRQEMKqhTGcDLQK7x',
#    'id': '0vrWqbRQEMKqhTGcDLQK7x',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273de48dc987cf862da9139e443',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02de48dc987cf862da9139e443',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851de48dc987cf862da9139e443',
#      'width': 64}],
#    'name': 'In The Lonely Hour (Drowning Shadows Edition)',
#    'release_date': '2015-11-06',
#    'release_date_precision': 'day',
#    'total_tracks': 23,
#    'type': 'album',
#    'uri': 'spotify:album:0vrWqbRQEMKqhTGcDLQK7x'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#     'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#     'id': '2wY79sveU1sp5g7SokKOiI',
#     'name': 'Sam Smith',
#     'type': 'artist',
#     'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 202268,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM71304978'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2QXmZCQwDsXxSgAGEEY5ep'},
#   'href': 'https://api.spotify.com/v1/tracks/2QXmZCQwDsXxSgAGEEY5ep',
#   'id': '2QXmZCQwDsXxSgAGEEY5ep',
#   'is_local': False,
#   'name': 'Nirvana',
#   'popularity': 57,
#   'preview_url': None,
#   'track_number': 17,
#   'type': 'track',
#   'uri': 'spotify:track:2QXmZCQwDsXxSgAGEEY5ep'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1To7kv722A8SpZF789MZy7'},
#    'href': 'https://api.spotify.com/v1/albums/1To7kv722A8SpZF789MZy7',
#    'id': '1To7kv722A8SpZF789MZy7',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27336c5417732e53e23cb219246',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0236c5417732e53e23cb219246',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485136c5417732e53e23cb219246',
#      'width': 64}],
#    'name': 'MTV Unplugged In New York',
#    'release_date': '1994-11-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1To7kv722A8SpZF789MZy7'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 261093,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19972704'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/15VRO9CQwMpbqUYA7e6Hwg'},
#   'href': 'https://api.spotify.com/v1/tracks/15VRO9CQwMpbqUYA7e6Hwg',
#   'id': '15VRO9CQwMpbqUYA7e6Hwg',
#   'is_local': False,
#   'name': 'The Man Who Sold The World',
#   'popularity': 74,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:15VRO9CQwMpbqUYA7e6Hwg'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7wOOA7l306K8HfBKfPoafr'},
#    'href': 'https://api.spotify.com/v1/albums/7wOOA7l306K8HfBKfPoafr',
#    'id': '7wOOA7l306K8HfBKfPoafr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c4f52ef8782f0e8ede4c1aaf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c4f52ef8782f0e8ede4c1aaf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c4f52ef8782f0e8ede4c1aaf',
#      'width': 64}],
#    'name': 'In Utero - 20th Anniversary Remaster',
#    'release_date': '1993-09-21',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:7wOOA7l306K8HfBKfPoafr'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 233173,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19960712'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1Ic9pKxGSJGM0LKeqf6lGe'},
#   'href': 'https://api.spotify.com/v1/tracks/1Ic9pKxGSJGM0LKeqf6lGe',
#   'id': '1Ic9pKxGSJGM0LKeqf6lGe',
#   'is_local': False,
#   'name': 'All Apologies',
#   'popularity': 69,
#   'preview_url': None,
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:1Ic9pKxGSJGM0LKeqf6lGe'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5zBPRXCAc801vyHWoRurNZ'},
#    'href': 'https://api.spotify.com/v1/albums/5zBPRXCAc801vyHWoRurNZ',
#    'id': '5zBPRXCAc801vyHWoRurNZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27356072fea6785a3ad2d24237c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0256072fea6785a3ad2d24237c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485156072fea6785a3ad2d24237c',
#      'width': 64}],
#    'name': 'Nirvana',
#    'release_date': '2002-10-29',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:5zBPRXCAc801vyHWoRurNZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 166640,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG10200084'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/55yvzYuvJYG2RUEnMK78tr'},
#   'href': 'https://api.spotify.com/v1/tracks/55yvzYuvJYG2RUEnMK78tr',
#   'id': '55yvzYuvJYG2RUEnMK78tr',
#   'is_local': False,
#   'name': 'About A Girl',
#   'popularity': 70,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:55yvzYuvJYG2RUEnMK78tr'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7wOOA7l306K8HfBKfPoafr'},
#    'href': 'https://api.spotify.com/v1/albums/7wOOA7l306K8HfBKfPoafr',
#    'id': '7wOOA7l306K8HfBKfPoafr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c4f52ef8782f0e8ede4c1aaf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c4f52ef8782f0e8ede4c1aaf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c4f52ef8782f0e8ede4c1aaf',
#      'width': 64}],
#    'name': 'In Utero - 20th Anniversary Remaster',
#    'release_date': '1993-09-21',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:7wOOA7l306K8HfBKfPoafr'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 151893,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19960706'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5gRcv46AMTrosmTOqrOV3Q'},
#   'href': 'https://api.spotify.com/v1/tracks/5gRcv46AMTrosmTOqrOV3Q',
#   'id': '5gRcv46AMTrosmTOqrOV3Q',
#   'is_local': False,
#   'name': 'Dumb',
#   'popularity': 68,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:5gRcv46AMTrosmTOqrOV3Q'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#    'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#    'id': '2guirTSEqLizK7j9i1MTTZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#      'width': 64}],
#    'name': 'Nevermind (Remastered)',
#    'release_date': '1991-09-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:2guirTSEqLizK7j9i1MTTZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 232146,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19942512'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1nFtiJxYdhtFfFtfXBv06s'},
#   'href': 'https://api.spotify.com/v1/tracks/1nFtiJxYdhtFfFtfXBv06s',
#   'id': '1nFtiJxYdhtFfFtfXBv06s',
#   'is_local': False,
#   'name': 'Something In The Way',
#   'popularity': 63,
#   'preview_url': None,
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:1nFtiJxYdhtFfFtfXBv06s'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#    'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#    'id': '2guirTSEqLizK7j9i1MTTZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#      'width': 640},
#     {'height': 300,
# ...
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4uFem464bjba6Gjkkn1ocM'},
#    'href': 'https://api.spotify.com/v1/albums/4uFem464bjba6Gjkkn1ocM',
#    'id': '4uFem464bjba6Gjkkn1ocM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273cc16967fc09cf6f07727d394',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02cc16967fc09cf6f07727d394',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851cc16967fc09cf6f07727d394',
#      'width': 64}],
#    'name': 'White Noise Nirvana',
#    'release_date': '2020-12-02',
#    'release_date_precision': 'day',
#    'total_tracks': 4,
#    'type': 'album',
#    'uri': 'spotify:album:4uFem464bjba6Gjkkn1ocM'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jLfCVXiXP2SoEA8BOIrxM'},
#     'href': 'https://api.spotify.com/v1/artists/6jLfCVXiXP2SoEA8BOIrxM',
#     'id': '6jLfCVXiXP2SoEA8BOIrxM',
#     'name': 'Noise Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6jLfCVXiXP2SoEA8BOIrxM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 189983,
#   'explicit': False,
#   'external_ids': {'isrc': 'SE6RB2050003'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5oFzhMtV6BO1uDGZeAyYar'},
#   'href': 'https://api.spotify.com/v1/tracks/5oFzhMtV6BO1uDGZeAyYar',
#   'id': '5oFzhMtV6BO1uDGZeAyYar',
#   'is_local': False,
#   'name': 'Peaceful White Noise',
#   'popularity': 55,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fb408c293245ddcaa3aeb360b3fb397fdbffc51e?cid=458a20bd06e9408c95af3d0901c21965',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:5oFzhMtV6BO1uDGZeAyYar'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7wOOA7l306K8HfBKfPoafr'},
#    'href': 'https://api.spotify.com/v1/albums/7wOOA7l306K8HfBKfPoafr',
#    'id': '7wOOA7l306K8HfBKfPoafr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c4f52ef8782f0e8ede4c1aaf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c4f52ef8782f0e8ede4c1aaf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c4f52ef8782f0e8ede4c1aaf',
#      'width': 64}],
#    'name': 'In Utero - 20th Anniversary Remaster',
#    'release_date': '1993-09-21',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:7wOOA7l306K8HfBKfPoafr'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 115813,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19960707'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0hUit24g1EIoATdKYWUiRj'},
#   'href': 'https://api.spotify.com/v1/tracks/0hUit24g1EIoATdKYWUiRj',
#   'id': '0hUit24g1EIoATdKYWUiRj',
#   'is_local': False,
#   'name': 'Very Ape',
#   'popularity': 56,
#   'preview_url': None,
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:0hUit24g1EIoATdKYWUiRj'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1To7kv722A8SpZF789MZy7'},
#    'href': 'https://api.spotify.com/v1/albums/1To7kv722A8SpZF789MZy7',
#    'id': '1To7kv722A8SpZF789MZy7',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27336c5417732e53e23cb219246',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0236c5417732e53e23cb219246',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485136c5417732e53e23cb219246',
#      'width': 64}],
#    'name': 'MTV Unplugged In New York',
#    'release_date': '1994-11-01',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1To7kv722A8SpZF789MZy7'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 172933,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19972706'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/725QAOexNLmGZiFMN7U8pF'},
#   'href': 'https://api.spotify.com/v1/tracks/725QAOexNLmGZiFMN7U8pF',
#   'id': '725QAOexNLmGZiFMN7U8pF',
#   'is_local': False,
#   'name': 'Dumb',
#   'popularity': 57,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:725QAOexNLmGZiFMN7U8pF'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#      'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#      'id': '6olE6TJLqED3rqDCT0FyPh',
#      'name': 'Nirvana',
#      'type': 'artist',
#      'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#    'available_markets': ['CA', 'MX', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2guirTSEqLizK7j9i1MTTZ'},
#    'href': 'https://api.spotify.com/v1/albums/2guirTSEqLizK7j9i1MTTZ',
#    'id': '2guirTSEqLizK7j9i1MTTZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e175a19e530c898d167d39bf',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e175a19e530c898d167d39bf',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e175a19e530c898d167d39bf',
#      'width': 64}],
#    'name': 'Nevermind (Remastered)',
#    'release_date': '1991-09-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:2guirTSEqLizK7j9i1MTTZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#     'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#     'id': '6olE6TJLqED3rqDCT0FyPh',
#     'name': 'Nirvana',
#     'type': 'artist',
#     'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'}],
#   'available_markets': ['CA', 'MX', 'US'],
#   'disc_number': 1,
#   'duration_ms': 403293,
#   'explicit': False,
#   'external_ids': {'isrc': 'USGF19942513'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0vNHCXmNzVa8h54SE3JDm7'},
#   'href': 'https://api.spotify.com/v1/tracks/0vNHCXmNzVa8h54SE3JDm7',
#   'id': '0vNHCXmNzVa8h54SE3JDm7',
#   'is_local': False,
#   'name': 'Endless, Nameless',
#   'popularity': 49,
#   'preview_url': None,
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:0vNHCXmNzVa8h54SE3JDm7'}]

# %%
#total items 

tot_items = [my_20_artists[i]['tracks']['items'] for i in  range(len(my_20_artists))]

# %%
# double indexing for artist and songs
# first artist, first song - Id
tot_items[0][0]['id']
# Out:
# '1FpAKPGuR8SoIUw5t0I5vn'

# %%
# get all the ids
# extrac all the id from each artist, from each track
tot_ids = [tot_items[artist][track]['id'] for track in range(0,50) for artist in range(len(my_20_artists))]
len(tot_ids)
# Out:
# 2550

# %%
tot_ids
# Out:
# ['1FpAKPGuR8SoIUw5t0I5vn',
#  '4v7SAP4KD96BFLWiCd1vF0',
#  '0A3JouZ9j02d15KoEzP6F0',
#  '5ghIJDpPoe3CfHMGu71E6T',
#  '74WjYdm3Lvbwnds4thYPUU',
#  '1HKl3RJInVzf5ObVnM644j',
#  '5BIMPccDwShpXq784RJlJp',
#  '0XtVfBWnnWDwZveSlsAyKx',
#  '6QJY9hgSJmbkXa16ypZy9G',
#  '2rfVX4zjVnfUOr1k3txKNG',
#  '3iNj5fdyY62N1ycufQ3E2M',
#  '3qBjnDMDQrSKXKkBHok6oo',
#  '5gBB6pY1xJ23DGpsf5eoij',
#  '6nxHMqTNKWlQnx5AFxz1iX',
#  '6K4t31amVTZDgR3sKmwUJJ',
#  '6kvoHl80mfCVTv7XnZkjQn',
#  '6ztWnPEhEO5QBMo1AOIDah',
#  '0zTSmiDzVkIPUPjsHcUWpe',
#  '1rmmyYF8hpdZ85E9mnW0ma',
#  '00YK79eSJUSO0dGNGB2CDs',
#  '2En6fFzzlzPLcV8sXwrx7X',
#  '6qgE98QF1vQ3A78rrgrn1M',
#  '2f9K9Gm9CLj0eKFW3BQZE8',
#  '1X2Z8Js9G8YmXIbrwSIptK',
#  '4QDbcjFOBHunn5P6vlSeuE',
#  '00xDcOBS1NwrxZlh3XfVr6',
#  '3NeiYiBn3rQBgurfVk92Zm',
#  '1cpANF6zMBoFoxkoIjZHjv',
#  '1LUsMGslRbetkks6jIjHzb',
#  '2aoo2jlRnM3A0NyLQqMN2f',
#  '3QyB8F5ZhYoai6qjC3evt4',
#  '5VXqnaVDKEFazcDt57pcVY',
#  '5uvosCdMlFdTXhoazkTI5R',
#  '1cJ0cJ7h00HviJTsLDmrsz',
#  '5lHgBqh9VwAAzQma55gHRY',
#  '6s5BwPPzz4bdY5aUHWzqAE',
#  '6DU1WKdUnR7OZkw7BZl9P0',
#  '1Z8gpnzgTFQKAwmV43iLBB',
#  '49rhyZLMgZZIsYcAQTnaHS',
#  '2EvUjCWg5zeaeKxGeOaHPh',
#  '3Ll5hNH3oNES1OTG3f4ZAd',
#  '1bM50INir8voAkVoKuvEUI',
#  '4yl1IpHPuXUV2MjxXy6hZn',
#  '3Ozx6IrGdoQyAworJzvBDE',
#  '7brHKGKFdRhzReovMw1T8z',
#  '2eHruBEy06Vt7VswO4ROhC',
#  '4UDyPXAzvzsNNjKNNdCGmp',
#  '3BTsv0FthgmDwyKlYShwJF',
#  '5tCjWV0DA1BXd2vs4UwF2z',
#  '1Y373MqadDRtclJNdnUXVc',
#  '5FAO8M86HZX9TFfBMR2isb',
#  '384TJj6XyHUyNlCbdgm6Sz',
#  '4Y6GIje3GErVRIq1Ff5BJq',
#  '7IQMKJNcppgahjNWVPmxkl',
#  '1mee9jicUVtzLghXPgvhrX',
#  '3jVa63TF8kkbzyIcbSWoBS',
#  '4BYGxv4rxSNcTgT3DsFB9o',
#  '12L4EdgpIWpza2vI0atLEA',
#  '1phDn3V7m4ugdYyz9J1MWk',
#  '0gWvVB4bGvADocoPMEDy3K',
#  '3ka5SjILvvjwRiVQzNRdRv',
#  '2cdCC1aCXbvz9tXFOR6CxR',
#  '75z4LIFEorndhHSb95Fams',
#  '2Q21yFRtD36STs8mWlpAYI',
#  '2KA3lvDwQQiyvuJJvzifGL',
#  '5eRdRHsWekPcNHbeDgroU8',
#  '6L3qfBftLvlKn1abLExMgp',
#  '35l1gFx8i5jp63KdyhYEmu',
#  '11OPriDpmUrTMTji52ta17',
#  '4gCMNhOZO3m260wEr5I4QZ',
#  '2kzRSiyignH8yzPTrWvyPo',
#  '7cpd1reKGwtclkeWhoiRIi',
#  '5JIeBZC4UAcixvi1Eqa2mQ',
#  '7lBmcEU1UyDj81hPlipxTs',
#  '4hVkQDEWRO2r1l5AxvxfJT',
#  '5281iZ2p4VVCGAvFLzmyDN',
#  '6q4yVOTF91QRCukCQ1IzTV',
#  '6NFQBzWxe0m548CZ6OCDFq',
#  '4dT1155sbuWZduYj0bgwKo',
#  '4KImfnZuVGuGt84MhfFc8M',
#  '1uDsJBIrwhtEN6KcTmhS40',
#  '5Rizj5FLb2AyNKu9esjYY6',
#  '4pCCSIQzxFsFPakL9LyUbc',
#  '0CETmgFGt8Ne8vLnaLcduU',
#  '7LHZ7HA45ezKcdN8sBrBuS',
#  '6DhRYmgbtdXQlJ638xaHGt',
#  '1fWrjQgezOFINFdjATTx7s',
#  '5ierkPgrIUtxNuHe5qE1AK',
#  '2LKUEwDNchYakrz7RVmWJG',
#  '0I4Jk0qIO6BWVYgKat9Gkt',
#  '1s3i3BG2d7s37nlbVu5Q1r',
#  '0ZDXI91Cf66bJRs3oG12xt',
#  '5ibXqGCuO5jGcb41gLlaZe',
#  '7Jwp98P2bsP5n5lE2We8GJ',
#  '6nVyNpN4OheP0ZWVhJqbl5',
#  '2EEjiKbE4pAjX49TrBzw1X',
#  '27K996qPlCcnWSxr3zkDg6',
#  '0I0urfvDfPytIxuu5zSzuY',
#  '5RjllqXO3v4BnhWLjpnEk3',
#  '3Njm5POmE3Bc9P7LzhIbG8',
#  '6ZqhSJIRchCyPHwYRryNx7',
#  '5YJstLbbwtemVuiGJjNRvl',
#  '1sK0siZs8cjQ6l3kN7n4Pc',
#  '2l0FKzrzU9Z1OO0Z2lb5hS',
#  '4s7q9p6OXz1dURyD9zphAG',
#  '37vEa9sfgAqEZuqX8AX0Zk',
#  '6D5ZtBikELea6jBanYvrIn',
#  '3f5JtAsGRIXN8pSAeTi6vA',
#  '2exaYdyy6H4o6SXkmt2y3I',
#  ...]

# %%
#get the audio features
sp.audio_features(tot_ids[:10])
# Out:
# [{'danceability': 0.87,
#   'energy': 0.587,
#   'key': 6,
#   'loudness': -6.117,
#   'mode': 1,
#   'speechiness': 0.0406,
#   'acousticness': 0.0209,
#   'instrumentalness': 3.18e-06,
#   'liveness': 0.0888,
#   'valence': 0.814,
#   'tempo': 122.939,
#   'type': 'audio_features',
#   'id': '1FpAKPGuR8SoIUw5t0I5vn',
#   'uri': 'spotify:track:1FpAKPGuR8SoIUw5t0I5vn',
#   'track_href': 'https://api.spotify.com/v1/tracks/1FpAKPGuR8SoIUw5t0I5vn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FpAKPGuR8SoIUw5t0I5vn',
#   'duration_ms': 191073,
#   'time_signature': 4},
#  {'danceability': 0.905,
#   'energy': 0.492,
#   'key': 2,
#   'loudness': -8.598,
#   'mode': 1,
#   'speechiness': 0.0595,
#   'acousticness': 0.0149,
#   'instrumentalness': 3.77e-05,
#   'liveness': 0.371,
#   'valence': 0.142,
#   'tempo': 110.017,
#   'type': 'audio_features',
#   'id': '4v7SAP4KD96BFLWiCd1vF0',
#   'uri': 'spotify:track:4v7SAP4KD96BFLWiCd1vF0',
#   'track_href': 'https://api.spotify.com/v1/tracks/4v7SAP4KD96BFLWiCd1vF0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4v7SAP4KD96BFLWiCd1vF0',
#   'duration_ms': 177840,
#   'time_signature': 4},
#  {'danceability': 0.827,
#   'energy': 0.189,
#   'key': 6,
#   'loudness': -9.37,
#   'mode': 0,
#   'speechiness': 0.0495,
#   'acousticness': 0.852,
#   'instrumentalness': 0.028,
#   'liveness': 0.109,
#   'valence': 0.485,
#   'tempo': 88.349,
#   'type': 'audio_features',
#   'id': '0A3JouZ9j02d15KoEzP6F0',
#   'uri': 'spotify:track:0A3JouZ9j02d15KoEzP6F0',
#   'track_href': 'https://api.spotify.com/v1/tracks/0A3JouZ9j02d15KoEzP6F0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0A3JouZ9j02d15KoEzP6F0',
#   'duration_ms': 192680,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.912,
#   'key': 1,
#   'loudness': -4.556,
#   'mode': 1,
#   'speechiness': 0.0564,
#   'acousticness': 2.55e-05,
#   'instrumentalness': 0.000173,
#   'liveness': 0.106,
#   'valence': 0.72,
#   'tempo': 116.761,
#   'type': 'audio_features',
#   'id': '5ghIJDpPoe3CfHMGu71E6T',
#   'uri': 'spotify:track:5ghIJDpPoe3CfHMGu71E6T',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ghIJDpPoe3CfHMGu71E6T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ghIJDpPoe3CfHMGu71E6T',
#   'duration_ms': 301920,
#   'time_signature': 4},
#  {'danceability': 0.212,
#   'energy': 0.301,
#   'key': 2,
#   'loudness': -12.505,
#   'mode': 1,
#   'speechiness': 0.0384,
#   'acousticness': 0.963,
#   'instrumentalness': 0.0033,
#   'liveness': 0.13,
#   'valence': 0.0798,
#   'tempo': 84.025,
#   'type': 'audio_features',
#   'id': '74WjYdm3Lvbwnds4thYPUU',
#   'uri': 'spotify:track:74WjYdm3Lvbwnds4thYPUU',
#   'track_href': 'https://api.spotify.com/v1/tracks/74WjYdm3Lvbwnds4thYPUU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74WjYdm3Lvbwnds4thYPUU',
#   'duration_ms': 177333,
#   'time_signature': 4},
#  {'danceability': 0.717,
#   'energy': 0.712,
#   'key': 0,
#   'loudness': -6.098,
#   'mode': 1,
#   'speechiness': 0.0765,
#   'acousticness': 0.00663,
#   'instrumentalness': 0,
#   'liveness': 0.0756,
#   'valence': 0.825,
#   'tempo': 97.019,
#   'type': 'audio_features',
#   'id': '1HKl3RJInVzf5ObVnM644j',
#   'uri': 'spotify:track:1HKl3RJInVzf5ObVnM644j',
#   'track_href': 'https://api.spotify.com/v1/tracks/1HKl3RJInVzf5ObVnM644j',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HKl3RJInVzf5ObVnM644j',
#   'duration_ms': 171172,
#   'time_signature': 4},
#  {'danceability': 0.579,
#   'energy': 0.824,
#   'key': 6,
#   'loudness': -8.71,
#   'mode': 0,
#   'speechiness': 0.03,
#   'acousticness': 0.00206,
#   'instrumentalness': 0.00903,
#   'liveness': 0.059,
#   'valence': 0.635,
#   'tempo': 123.331,
#   'type': 'audio_features',
#   'id': '5BIMPccDwShpXq784RJlJp',
#   'uri': 'spotify:track:5BIMPccDwShpXq784RJlJp',
#   'track_href': 'https://api.spotify.com/v1/tracks/5BIMPccDwShpXq784RJlJp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BIMPccDwShpXq784RJlJp',
#   'duration_ms': 331573,
#   'time_signature': 4},
#  {'danceability': 0.457,
#   'energy': 0.523,
#   'key': 0,
#   'loudness': -7.09,
#   'mode': 1,
#   'speechiness': 0.0353,
#   'acousticness': 0.606,
#   'instrumentalness': 6.43e-06,
#   'liveness': 0.103,
#   'valence': 0.376,
#   'tempo': 134.35,
#   'type': 'audio_features',
#   'id': '0XtVfBWnnWDwZveSlsAyKx',
#   'uri': 'spotify:track:0XtVfBWnnWDwZveSlsAyKx',
#   'track_href': 'https://api.spotify.com/v1/tracks/0XtVfBWnnWDwZveSlsAyKx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0XtVfBWnnWDwZveSlsAyKx',
#   'duration_ms': 264240,
#   'time_signature': 4},
#  {'danceability': 0.703,
#   'energy': 0.543,
#   'key': 10,
#   'loudness': -7.947,
#   'mode': 0,
#   'speechiness': 0.0326,
#   'acousticness': 0.251,
#   'instrumentalness': 0.000231,
#   'liveness': 0.113,
#   'valence': 0.0836,
#   'tempo': 95.026,
#   'type': 'audio_features',
#   'id': '6QJY9hgSJmbkXa16ypZy9G',
#   'uri': 'spotify:track:6QJY9hgSJmbkXa16ypZy9G',
#   'track_href': 'https://api.spotify.com/v1/tracks/6QJY9hgSJmbkXa16ypZy9G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QJY9hgSJmbkXa16ypZy9G',
#   'duration_ms': 207994,
#   'time_signature': 4},
#  {'danceability': 0.691,
#   'energy': 0.829,
#   'key': 7,
#   'loudness': -7.301,
#   'mode': 0,
#   'speechiness': 0.16,
#   'acousticness': 0.136,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.512,
#   'tempo': 91.003,
#   'type': 'audio_features',
#   'id': '2rfVX4zjVnfUOr1k3txKNG',
#   'uri': 'spotify:track:2rfVX4zjVnfUOr1k3txKNG',
#   'track_href': 'https://api.spotify.com/v1/tracks/2rfVX4zjVnfUOr1k3txKNG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2rfVX4zjVnfUOr1k3txKNG',
#   'duration_ms': 182978,
#   'time_signature': 4}]

# %%
# chunckin the tot_ids is needed to overcome the limit of 50 songsof spotipy
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

        
audio_feats = []
for chunk in list(chunks(tot_ids, 50)):
        audio_feats.append(sp.audio_features(chunk))

# %%
type(audio_feats)
# Out:
# list

# %%
audio_feats
# Out:
# [[{'danceability': 0.87,
#    'energy': 0.587,
#    'key': 6,
#    'loudness': -6.117,
#    'mode': 1,
#    'speechiness': 0.0406,
#    'acousticness': 0.0209,
#    'instrumentalness': 3.18e-06,
#    'liveness': 0.0888,
#    'valence': 0.814,
#    'tempo': 122.939,
#    'type': 'audio_features',
#    'id': '1FpAKPGuR8SoIUw5t0I5vn',
#    'uri': 'spotify:track:1FpAKPGuR8SoIUw5t0I5vn',
#    'track_href': 'https://api.spotify.com/v1/tracks/1FpAKPGuR8SoIUw5t0I5vn',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FpAKPGuR8SoIUw5t0I5vn',
#    'duration_ms': 191073,
#    'time_signature': 4},
#   {'danceability': 0.905,
#    'energy': 0.492,
#    'key': 2,
#    'loudness': -8.598,
#    'mode': 1,
#    'speechiness': 0.0595,
#    'acousticness': 0.0149,
#    'instrumentalness': 3.77e-05,
#    'liveness': 0.371,
#    'valence': 0.142,
#    'tempo': 110.017,
#    'type': 'audio_features',
#    'id': '4v7SAP4KD96BFLWiCd1vF0',
#    'uri': 'spotify:track:4v7SAP4KD96BFLWiCd1vF0',
#    'track_href': 'https://api.spotify.com/v1/tracks/4v7SAP4KD96BFLWiCd1vF0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4v7SAP4KD96BFLWiCd1vF0',
#    'duration_ms': 177840,
#    'time_signature': 4},
#   {'danceability': 0.827,
#    'energy': 0.189,
#    'key': 6,
#    'loudness': -9.37,
#    'mode': 0,
#    'speechiness': 0.0495,
#    'acousticness': 0.852,
#    'instrumentalness': 0.028,
#    'liveness': 0.109,
#    'valence': 0.485,
#    'tempo': 88.349,
#    'type': 'audio_features',
#    'id': '0A3JouZ9j02d15KoEzP6F0',
#    'uri': 'spotify:track:0A3JouZ9j02d15KoEzP6F0',
#    'track_href': 'https://api.spotify.com/v1/tracks/0A3JouZ9j02d15KoEzP6F0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0A3JouZ9j02d15KoEzP6F0',
#    'duration_ms': 192680,
#    'time_signature': 4},
#   {'danceability': 0.502,
#    'energy': 0.912,
#    'key': 1,
#    'loudness': -4.556,
#    'mode': 1,
#    'speechiness': 0.0564,
#    'acousticness': 2.55e-05,
#    'instrumentalness': 0.000173,
#    'liveness': 0.106,
#    'valence': 0.72,
#    'tempo': 116.761,
#    'type': 'audio_features',
#    'id': '5ghIJDpPoe3CfHMGu71E6T',
#    'uri': 'spotify:track:5ghIJDpPoe3CfHMGu71E6T',
#    'track_href': 'https://api.spotify.com/v1/tracks/5ghIJDpPoe3CfHMGu71E6T',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ghIJDpPoe3CfHMGu71E6T',
#    'duration_ms': 301920,
#    'time_signature': 4},
#   {'danceability': 0.212,
#    'energy': 0.301,
#    'key': 2,
#    'loudness': -12.505,
#    'mode': 1,
#    'speechiness': 0.0384,
#    'acousticness': 0.963,
#    'instrumentalness': 0.0033,
#    'liveness': 0.13,
#    'valence': 0.0798,
#    'tempo': 84.025,
#    'type': 'audio_features',
#    'id': '74WjYdm3Lvbwnds4thYPUU',
#    'uri': 'spotify:track:74WjYdm3Lvbwnds4thYPUU',
#    'track_href': 'https://api.spotify.com/v1/tracks/74WjYdm3Lvbwnds4thYPUU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74WjYdm3Lvbwnds4thYPUU',
#    'duration_ms': 177333,
#    'time_signature': 4},
#   {'danceability': 0.717,
#    'energy': 0.712,
#    'key': 0,
#    'loudness': -6.098,
#    'mode': 1,
#    'speechiness': 0.0765,
#    'acousticness': 0.00663,
#    'instrumentalness': 0,
#    'liveness': 0.0756,
#    'valence': 0.825,
#    'tempo': 97.019,
#    'type': 'audio_features',
#    'id': '1HKl3RJInVzf5ObVnM644j',
#    'uri': 'spotify:track:1HKl3RJInVzf5ObVnM644j',
#    'track_href': 'https://api.spotify.com/v1/tracks/1HKl3RJInVzf5ObVnM644j',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HKl3RJInVzf5ObVnM644j',
#    'duration_ms': 171172,
#    'time_signature': 4},
#   {'danceability': 0.579,
#    'energy': 0.824,
#    'key': 6,
#    'loudness': -8.71,
#    'mode': 0,
#    'speechiness': 0.03,
#    'acousticness': 0.00206,
#    'instrumentalness': 0.00903,
#    'liveness': 0.059,
#    'valence': 0.635,
#    'tempo': 123.331,
#    'type': 'audio_features',
#    'id': '5BIMPccDwShpXq784RJlJp',
#    'uri': 'spotify:track:5BIMPccDwShpXq784RJlJp',
#    'track_href': 'https://api.spotify.com/v1/tracks/5BIMPccDwShpXq784RJlJp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5BIMPccDwShpXq784RJlJp',
#    'duration_ms': 331573,
#    'time_signature': 4},
#   {'danceability': 0.457,
#    'energy': 0.523,
#    'key': 0,
#    'loudness': -7.09,
#    'mode': 1,
#    'speechiness': 0.0353,
#    'acousticness': 0.606,
#    'instrumentalness': 6.43e-06,
#    'liveness': 0.103,
#    'valence': 0.376,
#    'tempo': 134.35,
#    'type': 'audio_features',
#    'id': '0XtVfBWnnWDwZveSlsAyKx',
#    'uri': 'spotify:track:0XtVfBWnnWDwZveSlsAyKx',
#    'track_href': 'https://api.spotify.com/v1/tracks/0XtVfBWnnWDwZveSlsAyKx',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0XtVfBWnnWDwZveSlsAyKx',
#    'duration_ms': 264240,
#    'time_signature': 4},
#   {'danceability': 0.703,
#    'energy': 0.543,
#    'key': 10,
#    'loudness': -7.947,
#    'mode': 0,
#    'speechiness': 0.0326,
#    'acousticness': 0.251,
#    'instrumentalness': 0.000231,
#    'liveness': 0.113,
#    'valence': 0.0836,
#    'tempo': 95.026,
#    'type': 'audio_features',
#    'id': '6QJY9hgSJmbkXa16ypZy9G',
#    'uri': 'spotify:track:6QJY9hgSJmbkXa16ypZy9G',
#    'track_href': 'https://api.spotify.com/v1/tracks/6QJY9hgSJmbkXa16ypZy9G',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QJY9hgSJmbkXa16ypZy9G',
#    'duration_ms': 207994,
#    'time_signature': 4},
#   {'danceability': 0.691,
#    'energy': 0.829,
#    'key': 7,
#    'loudness': -7.301,
#    'mode': 0,
#    'speechiness': 0.16,
#    'acousticness': 0.136,
#    'instrumentalness': 0,
#    'liveness': 0.11,
#    'valence': 0.512,
#    'tempo': 91.003,
#    'type': 'audio_features',
#    'id': '2rfVX4zjVnfUOr1k3txKNG',
#    'uri': 'spotify:track:2rfVX4zjVnfUOr1k3txKNG',
#    'track_href': 'https://api.spotify.com/v1/tracks/2rfVX4zjVnfUOr1k3txKNG',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2rfVX4zjVnfUOr1k3txKNG',
#    'duration_ms': 182978,
#    'time_signature': 4},
#   {'danceability': 0.409,
#    'energy': 0.848,
#    'key': 1,
#    'loudness': -9.797,
#    'mode': 1,
#    'speechiness': 0.0328,
#    'acousticness': 0.00563,
#    'instrumentalness': 0.92,
#    'liveness': 0.128,
#    'valence': 0.258,
#    'tempo': 165.928,
#    'type': 'audio_features',
#    'id': '3iNj5fdyY62N1ycufQ3E2M',
#    'uri': 'spotify:track:3iNj5fdyY62N1ycufQ3E2M',
#    'track_href': 'https://api.spotify.com/v1/tracks/3iNj5fdyY62N1ycufQ3E2M',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3iNj5fdyY62N1ycufQ3E2M',
#    'duration_ms': 223013,
#    'time_signature': 4},
#   {'danceability': 0.299,
#    'energy': 0.0326,
#    'key': 3,
#    'loudness': -31.81,
#    'mode': 1,
#    'speechiness': 0.0388,
#    'acousticness': 0.993,
#    'instrumentalness': 0.891,
#    'liveness': 0.111,
#    'valence': 0.0938,
#    'tempo': 81.426,
#    'type': 'audio_features',
#    'id': '3qBjnDMDQrSKXKkBHok6oo',
#    'uri': 'spotify:track:3qBjnDMDQrSKXKkBHok6oo',
#    'track_href': 'https://api.spotify.com/v1/tracks/3qBjnDMDQrSKXKkBHok6oo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qBjnDMDQrSKXKkBHok6oo',
#    'duration_ms': 178000,
#    'time_signature': 3},
#   {'danceability': 0.656,
#    'energy': 0.675,
#    'key': 0,
#    'loudness': -7.324,
#    'mode': 1,
#    'speechiness': 0.0261,
#    'acousticness': 0.297,
#    'instrumentalness': 0.00233,
#    'liveness': 0.451,
#    'valence': 0.675,
#    'tempo': 100.766,
#    'type': 'audio_features',
#    'id': '5gBB6pY1xJ23DGpsf5eoij',
#    'uri': 'spotify:track:5gBB6pY1xJ23DGpsf5eoij',
#    'track_href': 'https://api.spotify.com/v1/tracks/5gBB6pY1xJ23DGpsf5eoij',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5gBB6pY1xJ23DGpsf5eoij',
#    'duration_ms': 173973,
#    'time_signature': 4},
#   {'danceability': 0.497,
#    'energy': 0.947,
#    'key': 0,
#    'loudness': -8.802,
#    'mode': 1,
#    'speechiness': 0.0391,
#    'acousticness': 8.21e-05,
#    'instrumentalness': 0.000693,
#    'liveness': 0.118,
#    'valence': 0.588,
#    'tempo': 90.371,
#    'type': 'audio_features',
#    'id': '6nxHMqTNKWlQnx5AFxz1iX',
#    'uri': 'spotify:track:6nxHMqTNKWlQnx5AFxz1iX',
#    'track_href': 'https://api.spotify.com/v1/tracks/6nxHMqTNKWlQnx5AFxz1iX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nxHMqTNKWlQnx5AFxz1iX',
#    'duration_ms': 217907,
#    'time_signature': 4},
#   {'danceability': 0.64,
#    'energy': 0.74,
#    'key': 4,
#    'loudness': -4.083,
#    'mode': 1,
#    'speechiness': 0.0284,
#    'acousticness': 0.0115,
#    'instrumentalness': 0.00678,
#    'liveness': 0.167,
#    'valence': 0.785,
#    'tempo': 116.879,
#    'type': 'audio_features',
#    'id': '6K4t31amVTZDgR3sKmwUJJ',
#    'uri': 'spotify:track:6K4t31amVTZDgR3sKmwUJJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/6K4t31amVTZDgR3sKmwUJJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6K4t31amVTZDgR3sKmwUJJ',
#    'duration_ms': 216320,
#    'time_signature': 4},
#   {'danceability': 0.52,
#    'energy': 0.652,
#    'key': 5,
#    'loudness': -6.655,
#    'mode': 1,
#    'speechiness': 0.0274,
#    'acousticness': 0.34,
#    'instrumentalness': 5.49e-05,
#    'liveness': 0.256,
#    'valence': 0.722,
#    'tempo': 80.609,
#    'type': 'audio_features',
#    'id': '6kvoHl80mfCVTv7XnZkjQn',
#    'uri': 'spotify:track:6kvoHl80mfCVTv7XnZkjQn',
#    'track_href': 'https://api.spotify.com/v1/tracks/6kvoHl80mfCVTv7XnZkjQn',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6kvoHl80mfCVTv7XnZkjQn',
#    'duration_ms': 258787,
#    'time_signature': 4},
#   {'danceability': 0.691,
#    'energy': 0.973,
#    'key': 2,
#    'loudness': -3.586,
#    'mode': 1,
#    'speechiness': 0.048,
#    'acousticness': 0.126,
#    'instrumentalness': 0,
#    'liveness': 0.101,
#    'valence': 0.783,
#    'tempo': 143.961,
#    'type': 'audio_features',
#    'id': '6ztWnPEhEO5QBMo1AOIDah',
#    'uri': 'spotify:track:6ztWnPEhEO5QBMo1AOIDah',
#    'track_href': 'https://api.spotify.com/v1/tracks/6ztWnPEhEO5QBMo1AOIDah',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ztWnPEhEO5QBMo1AOIDah',
#    'duration_ms': 231533,
#    'time_signature': 4},
#   {'danceability': 0.433,
#    'energy': 0.123,
#    'key': 1,
#    'loudness': -11.234,
#    'mode': 0,
#    'speechiness': 0.0468,
#    'acousticness': 0.887,
#    'instrumentalness': 0,
#    'liveness': 0.106,
#    'valence': 0.137,
#    'tempo': 181.882,
#    'type': 'audio_features',
#    'id': '0zTSmiDzVkIPUPjsHcUWpe',
#    'uri': 'spotify:track:0zTSmiDzVkIPUPjsHcUWpe',
#    'track_href': 'https://api.spotify.com/v1/tracks/0zTSmiDzVkIPUPjsHcUWpe',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0zTSmiDzVkIPUPjsHcUWpe',
#    'duration_ms': 244973,
#    'time_signature': 4},
#   {'danceability': 0.47,
#    'energy': 0.125,
#    'key': 0,
#    'loudness': -16.399,
#    'mode': 1,
#    'speechiness': 0.0445,
#    'acousticness': 0.965,
#    'instrumentalness': 1.82e-05,
#    'liveness': 0.354,
#    'valence': 0.187,
#    'tempo': 128.603,
#    'type': 'audio_features',
#    'id': '1rmmyYF8hpdZ85E9mnW0ma',
#    'uri': 'spotify:track:1rmmyYF8hpdZ85E9mnW0ma',
#    'track_href': 'https://api.spotify.com/v1/tracks/1rmmyYF8hpdZ85E9mnW0ma',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1rmmyYF8hpdZ85E9mnW0ma',
#    'duration_ms': 155587,
#    'time_signature': 4},
#   {'danceability': 0.786,
#    'energy': 0.621,
#    'key': 7,
#    'loudness': -9.805,
#    'mode': 0,
#    'speechiness': 0.0282,
#    'acousticness': 0.576,
#    'instrumentalness': 0.000404,
#    'liveness': 0.123,
#    'valence': 0.54,
#    'tempo': 111.459,
#    'type': 'audio_features',
#    'id': '00YK79eSJUSO0dGNGB2CDs',
#    'uri': 'spotify:track:00YK79eSJUSO0dGNGB2CDs',
#    'track_href': 'https://api.spotify.com/v1/tracks/00YK79eSJUSO0dGNGB2CDs',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00YK79eSJUSO0dGNGB2CDs',
#    'duration_ms': 164360,
#    'time_signature': 4},
#   {'danceability': 0.636,
#    'energy': 0.52,
#    'key': 11,
#    'loudness': -13.511,
#    'mode': 1,
#    'speechiness': 0.03,
#    'acousticness': 0.00168,
#    'instrumentalness': 0.00481,
#    'liveness': 0.212,
#    'valence': 0.853,
#    'tempo': 115.121,
#    'type': 'audio_features',
#    'id': '2En6fFzzlzPLcV8sXwrx7X',
#    'uri': 'spotify:track:2En6fFzzlzPLcV8sXwrx7X',
#    'track_href': 'https://api.spotify.com/v1/tracks/2En6fFzzlzPLcV8sXwrx7X',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2En6fFzzlzPLcV8sXwrx7X',
#    'duration_ms': 248707,
#    'time_signature': 4},
#   {'danceability': 0.513,
#    'energy': 0.48,
#    'key': 5,
#    'loudness': -9.575,
#    'mode': 0,
#    'speechiness': 0.125,
#    'acousticness': 0.614,
#    'instrumentalness': 0,
#    'liveness': 0.0923,
#    'valence': 0.595,
#    'tempo': 81.484,
#    'type': 'audio_features',
#    'id': '6qgE98QF1vQ3A78rrgrn1M',
#    'uri': 'spotify:track:6qgE98QF1vQ3A78rrgrn1M',
#    'track_href': 'https://api.spotify.com/v1/tracks/6qgE98QF1vQ3A78rrgrn1M',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6qgE98QF1vQ3A78rrgrn1M',
#    'duration_ms': 222912,
#    'time_signature': 4},
#   {'danceability': 0.391,
#    'energy': 0.86,
#    'key': 1,
#    'loudness': -5.54,
#    'mode': 1,
#    'speechiness': 0.0461,
#    'acousticness': 0.0642,
#    'instrumentalness': 0.939,
#    'liveness': 0.0792,
#    'valence': 0.141,
#    'tempo': 120.108,
#    'type': 'audio_features',
#    'id': '2f9K9Gm9CLj0eKFW3BQZE8',
#    'uri': 'spotify:track:2f9K9Gm9CLj0eKFW3BQZE8',
#    'track_href': 'https://api.spotify.com/v1/tracks/2f9K9Gm9CLj0eKFW3BQZE8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2f9K9Gm9CLj0eKFW3BQZE8',
#    'duration_ms': 301840,
#    'time_signature': 4},
#   {'danceability': 0.581,
#    'energy': 0.293,
#    'key': 7,
#    'loudness': -10.918,
#    'mode': 1,
#    'speechiness': 0.038,
#    'acousticness': 0.802,
#    'instrumentalness': 0,
#    'liveness': 0.0873,
#    'valence': 0.364,
#    'tempo': 127.162,
#    'type': 'audio_features',
#    'id': '1X2Z8Js9G8YmXIbrwSIptK',
#    'uri': 'spotify:track:1X2Z8Js9G8YmXIbrwSIptK',
#    'track_href': 'https://api.spotify.com/v1/tracks/1X2Z8Js9G8YmXIbrwSIptK',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1X2Z8Js9G8YmXIbrwSIptK',
#    'duration_ms': 272240,
#    'time_signature': 3},
#   {'danceability': 0.657,
#    'energy': 0.186,
#    'key': 6,
#    'loudness': -16.317,
#    'mode': 1,
#    'speechiness': 0.0611,
#    'acousticness': 0.92,
#    'instrumentalness': 0.000132,
#    'liveness': 0.0799,
#    'valence': 0.587,
#    'tempo': 79.543,
#    'type': 'audio_features',
#    'id': '4QDbcjFOBHunn5P6vlSeuE',
#    'uri': 'spotify:track:4QDbcjFOBHunn5P6vlSeuE',
#    'track_href': 'https://api.spotify.com/v1/tracks/4QDbcjFOBHunn5P6vlSeuE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4QDbcjFOBHunn5P6vlSeuE',
#    'duration_ms': 221400,
#    'time_signature': 4},
#   {'danceability': 0.595,
#    'energy': 0.82,
#    'key': 2,
#    'loudness': -7.913,
#    'mode': 0,
#    'speechiness': 0.0865,
#    'acousticness': 0.417,
#    'instrumentalness': 0.502,
#    'liveness': 0.13,
#    'valence': 0.622,
#    'tempo': 137.17,
#    'type': 'audio_features',
#    'id': '00xDcOBS1NwrxZlh3XfVr6',
#    'uri': 'spotify:track:00xDcOBS1NwrxZlh3XfVr6',
#    'track_href': 'https://api.spotify.com/v1/tracks/00xDcOBS1NwrxZlh3XfVr6',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00xDcOBS1NwrxZlh3XfVr6',
#    'duration_ms': 373813,
#    'time_signature': 4},
#   {'danceability': 0.632,
#    'energy': 0.807,
#    'key': 0,
#    'loudness': -5.893,
#    'mode': 1,
#    'speechiness': 0.126,
#    'acousticness': 0.144,
#    'instrumentalness': 0.0211,
#    'liveness': 0.125,
#    'valence': 0.784,
#    'tempo': 160.174,
#    'type': 'audio_features',
#    'id': '3NeiYiBn3rQBgurfVk92Zm',
#    'uri': 'spotify:track:3NeiYiBn3rQBgurfVk92Zm',
#    'track_href': 'https://api.spotify.com/v1/tracks/3NeiYiBn3rQBgurfVk92Zm',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3NeiYiBn3rQBgurfVk92Zm',
#    'duration_ms': 197933,
#    'time_signature': 4},
#   {'danceability': 0.478,
#    'energy': 0.0294,
#    'key': 0,
#    'loudness': -25.319,
#    'mode': 1,
#    'speechiness': 0.0453,
#    'acousticness': 0.993,
#    'instrumentalness': 0.948,
#    'liveness': 0.105,
#    'valence': 0.148,
#    'tempo': 124.308,
#    'type': 'audio_features',
#    'id': '1cpANF6zMBoFoxkoIjZHjv',
#    'uri': 'spotify:track:1cpANF6zMBoFoxkoIjZHjv',
#    'track_href': 'https://api.spotify.com/v1/tracks/1cpANF6zMBoFoxkoIjZHjv',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1cpANF6zMBoFoxkoIjZHjv',
#    'duration_ms': 324200,
#    'time_signature': 3},
#   {'danceability': 0.555,
#    'energy': 0.622,
#    'key': 9,
#    'loudness': -12.245,
#    'mode': 1,
#    'speechiness': 0.031,
#    'acousticness': 0.00208,
#    'instrumentalness': 0.162,
#    'liveness': 0.147,
#    'valence': 0.734,
#    'tempo': 156.415,
#    'type': 'audio_features',
#    'id': '1LUsMGslRbetkks6jIjHzb',
#    'uri': 'spotify:track:1LUsMGslRbetkks6jIjHzb',
#    'track_href': 'https://api.spotify.com/v1/tracks/1LUsMGslRbetkks6jIjHzb',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1LUsMGslRbetkks6jIjHzb',
#    'duration_ms': 354747,
#    'time_signature': 4},
#   {'danceability': 0.438,
#    'energy': 0.805,
#    'key': 8,
#    'loudness': -6.237,
#    'mode': 1,
#    'speechiness': 0.0624,
#    'acousticness': 0.00255,
#    'instrumentalness': 5.69e-05,
#    'liveness': 0.0842,
#    'valence': 0.564,
#    'tempo': 113.253,
#    'type': 'audio_features',
#    'id': '2aoo2jlRnM3A0NyLQqMN2f',
#    'uri': 'spotify:track:2aoo2jlRnM3A0NyLQqMN2f',
#    'track_href': 'https://api.spotify.com/v1/tracks/2aoo2jlRnM3A0NyLQqMN2f',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2aoo2jlRnM3A0NyLQqMN2f',
#    'duration_ms': 240800,
#    'time_signature': 4},
#   {'danceability': 0.819,
#    'energy': 0.705,
#    'key': 4,
#    'loudness': -7.245,
#    'mode': 0,
#    'speechiness': 0.0365,
#    'acousticness': 0.162,
#    'instrumentalness': 0.000543,
#    'liveness': 0.0666,
#    'valence': 0.976,
#    'tempo': 112.248,
#    'type': 'audio_features',
#    'id': '3QyB8F5ZhYoai6qjC3evt4',
#    'uri': 'spotify:track:3QyB8F5ZhYoai6qjC3evt4',
#    'track_href': 'https://api.spotify.com/v1/tracks/3QyB8F5ZhYoai6qjC3evt4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QyB8F5ZhYoai6qjC3evt4',
#    'duration_ms': 182013,
#    'time_signature': 4},
#   {'danceability': 0.367,
#    'energy': 0.019,
#    'key': 1,
#    'loudness': -28.121,
#    'mode': 1,
#    'speechiness': 0.0542,
#    'acousticness': 0.993,
#    'instrumentalness': 0.914,
#    'liveness': 0.0698,
#    'valence': 0.0391,
#    'tempo': 169.443,
#    'type': 'audio_features',
#    'id': '5VXqnaVDKEFazcDt57pcVY',
#    'uri': 'spotify:track:5VXqnaVDKEFazcDt57pcVY',
#    'track_href': 'https://api.spotify.com/v1/tracks/5VXqnaVDKEFazcDt57pcVY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5VXqnaVDKEFazcDt57pcVY',
#    'duration_ms': 357653,
#    'time_signature': 3},
#   {'danceability': 0.413,
#    'energy': 0.725,
#    'key': 3,
#    'loudness': -5.787,
#    'mode': 0,
#    'speechiness': 0.0324,
#    'acousticness': 0.369,
#    'instrumentalness': 2.16e-05,
#    'liveness': 0.0905,
#    'valence': 0.44,
#    'tempo': 124.618,
#    'type': 'audio_features',
#    'id': '5uvosCdMlFdTXhoazkTI5R',
#    'uri': 'spotify:track:5uvosCdMlFdTXhoazkTI5R',
#    'track_href': 'https://api.spotify.com/v1/tracks/5uvosCdMlFdTXhoazkTI5R',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5uvosCdMlFdTXhoazkTI5R',
#    'duration_ms': 429760,
#    'time_signature': 4},
#   {'danceability': 0.595,
#    'energy': 0.902,
#    'key': 7,
#    'loudness': -8.483,
#    'mode': 1,
#    'speechiness': 0.0429,
#    'acousticness': 0.225,
#    'instrumentalness': 2.13e-05,
#    'liveness': 0.0734,
#    'valence': 0.669,
#    'tempo': 120.536,
#    'type': 'audio_features',
#    'id': '1cJ0cJ7h00HviJTsLDmrsz',
#    'uri': 'spotify:track:1cJ0cJ7h00HviJTsLDmrsz',
#    'track_href': 'https://api.spotify.com/v1/tracks/1cJ0cJ7h00HviJTsLDmrsz',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1cJ0cJ7h00HviJTsLDmrsz',
#    'duration_ms': 196800,
#    'time_signature': 4},
#   {'danceability': 0.291,
#    'energy': 0.493,
#    'key': 7,
#    'loudness': -9.461,
#    'mode': 1,
#    'speechiness': 0.028,
#    'acousticness': 0.0519,
#    'instrumentalness': 9.15e-06,
#    'liveness': 0.101,
#    'valence': 0.183,
#    'tempo': 182.032,
#    'type': 'audio_features',
#    'id': '5lHgBqh9VwAAzQma55gHRY',
#    'uri': 'spotify:track:5lHgBqh9VwAAzQma55gHRY',
#    'track_href': 'https://api.spotify.com/v1/tracks/5lHgBqh9VwAAzQma55gHRY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5lHgBqh9VwAAzQma55gHRY',
#    'duration_ms': 196187,
#    'time_signature': 3},
#   {'danceability': 0.341,
#    'energy': 0.527,
#    'key': 5,
#    'loudness': -11.066,
#    'mode': 1,
#    'speechiness': 0.0301,
#    'acousticness': 0.746,
#    'instrumentalness': 0.889,
#    'liveness': 0.0988,
#    'valence': 0.505,
#    'tempo': 98.193,
#    'type': 'audio_features',
#    'id': '6s5BwPPzz4bdY5aUHWzqAE',
#    'uri': 'spotify:track:6s5BwPPzz4bdY5aUHWzqAE',
#    'track_href': 'https://api.spotify.com/v1/tracks/6s5BwPPzz4bdY5aUHWzqAE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6s5BwPPzz4bdY5aUHWzqAE',
#    'duration_ms': 526293,
#    'time_signature': 4},
#   {'danceability': 0.0811,
#    'energy': 0.658,
#    'key': 11,
#    'loudness': -6.804,
#    'mode': 1,
#    'speechiness': 0.051,
#    'acousticness': 1.41e-05,
#    'instrumentalness': 0.903,
#    'liveness': 0.111,
#    'valence': 0.251,
#    'tempo': 62.825,
#    'type': 'audio_features',
#    'id': '6DU1WKdUnR7OZkw7BZl9P0',
#    'uri': 'spotify:track:6DU1WKdUnR7OZkw7BZl9P0',
#    'track_href': 'https://api.spotify.com/v1/tracks/6DU1WKdUnR7OZkw7BZl9P0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6DU1WKdUnR7OZkw7BZl9P0',
#    'duration_ms': 523333,
#    'time_signature': 4},
#   {'danceability': 0.642,
#    'energy': 0.538,
#    'key': 8,
#    'loudness': -7.206,
#    'mode': 1,
#    'speechiness': 0.0696,
#    'acousticness': 0.0242,
#    'instrumentalness': 0,
#    'liveness': 0.273,
#    'valence': 0.57,
#    'tempo': 143.921,
#    'type': 'audio_features',
#    'id': '1Z8gpnzgTFQKAwmV43iLBB',
#    'uri': 'spotify:track:1Z8gpnzgTFQKAwmV43iLBB',
#    'track_href': 'https://api.spotify.com/v1/tracks/1Z8gpnzgTFQKAwmV43iLBB',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Z8gpnzgTFQKAwmV43iLBB',
#    'duration_ms': 150160,
#    'time_signature': 4},
#   {'danceability': 0.441,
#    'energy': 0.319,
#    'key': 5,
#    'loudness': -11.847,
#    'mode': 1,
#    'speechiness': 0.0302,
#    'acousticness': 0.544,
#    'instrumentalness': 0.918,
#    'liveness': 0.11,
#    'valence': 0.216,
#    'tempo': 94.513,
#    'type': 'audio_features',
#    'id': '49rhyZLMgZZIsYcAQTnaHS',
#    'uri': 'spotify:track:49rhyZLMgZZIsYcAQTnaHS',
#    'track_href': 'https://api.spotify.com/v1/tracks/49rhyZLMgZZIsYcAQTnaHS',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/49rhyZLMgZZIsYcAQTnaHS',
#    'duration_ms': 724659,
#    'time_signature': 4},
#   {'danceability': 0.306,
#    'energy': 0.937,
#    'key': 8,
#    'loudness': -8.014,
#    'mode': 1,
#    'speechiness': 0.117,
#    'acousticness': 0.000177,
#    'instrumentalness': 0.0119,
#    'liveness': 0.0864,
#    'valence': 0.218,
#    'tempo': 157.345,
#    'type': 'audio_features',
#    'id': '2EvUjCWg5zeaeKxGeOaHPh',
#    'uri': 'spotify:track:2EvUjCWg5zeaeKxGeOaHPh',
#    'track_href': 'https://api.spotify.com/v1/tracks/2EvUjCWg5zeaeKxGeOaHPh',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2EvUjCWg5zeaeKxGeOaHPh',
#    'duration_ms': 213493,
#    'time_signature': 4},
#   {'danceability': 0.584,
#    'energy': 0.594,
#    'key': 0,
#    'loudness': -8.74,
#    'mode': 1,
#    'speechiness': 0.036,
#    'acousticness': 0.0308,
#    'instrumentalness': 0.092,
#    'liveness': 0.069,
#    'valence': 0.148,
#    'tempo': 143.011,
#    'type': 'audio_features',
#    'id': '3Ll5hNH3oNES1OTG3f4ZAd',
#    'uri': 'spotify:track:3Ll5hNH3oNES1OTG3f4ZAd',
#    'track_href': 'https://api.spotify.com/v1/tracks/3Ll5hNH3oNES1OTG3f4ZAd',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Ll5hNH3oNES1OTG3f4ZAd',
#    'duration_ms': 270893,
#    'time_signature': 4},
#   {'danceability': 0.781,
#    'energy': 0.745,
#    'key': 4,
#    'loudness': -5.81,
#    'mode': 0,
#    'speechiness': 0.0332,
#    'acousticness': 0.198,
#    'instrumentalness': 1.14e-05,
#    'liveness': 0.36,
#    'valence': 0.326,
#    'tempo': 129.998,
#    'type': 'audio_features',
#    'id': '1bM50INir8voAkVoKuvEUI',
#    'uri': 'spotify:track:1bM50INir8voAkVoKuvEUI',
#    'track_href': 'https://api.spotify.com/v1/tracks/1bM50INir8voAkVoKuvEUI',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bM50INir8voAkVoKuvEUI',
#    'duration_ms': 269493,
#    'time_signature': 4},
#   {'danceability': 0.172,
#    'energy': 0.904,
#    'key': 11,
#    'loudness': -4.831,
#    'mode': 1,
#    'speechiness': 0.0586,
#    'acousticness': 5.37e-05,
#    'instrumentalness': 0.229,
#    'liveness': 0.267,
#    'valence': 0.302,
#    'tempo': 135.149,
#    'type': 'audio_features',
#    'id': '4yl1IpHPuXUV2MjxXy6hZn',
#    'uri': 'spotify:track:4yl1IpHPuXUV2MjxXy6hZn',
#    'track_href': 'https://api.spotify.com/v1/tracks/4yl1IpHPuXUV2MjxXy6hZn',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yl1IpHPuXUV2MjxXy6hZn',
#    'duration_ms': 343307,
#    'time_signature': 4},
#   {'danceability': 0.567,
#    'energy': 0.311,
#    'key': 2,
#    'loudness': -14.464,
#    'mode': 0,
#    'speechiness': 0.0455,
#    'acousticness': 0.822,
#    'instrumentalness': 0.23,
#    'liveness': 0.11,
#    'valence': 0.478,
#    'tempo': 83.11,
#    'type': 'audio_features',
#    'id': '3Ozx6IrGdoQyAworJzvBDE',
#    'uri': 'spotify:track:3Ozx6IrGdoQyAworJzvBDE',
#    'track_href': 'https://api.spotify.com/v1/tracks/3Ozx6IrGdoQyAworJzvBDE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Ozx6IrGdoQyAworJzvBDE',
#    'duration_ms': 192480,
#    'time_signature': 4},
#   {'danceability': 0.354,
#    'energy': 0.867,
#    'key': 5,
#    'loudness': -5.078,
#    'mode': 1,
#    'speechiness': 0.0362,
#    'acousticness': 4.64e-05,
#    'instrumentalness': 0.404,
#    'liveness': 0.0748,
#    'valence': 0.436,
#    'tempo': 93.389,
#    'type': 'audio_features',
#    'id': '7brHKGKFdRhzReovMw1T8z',
#    'uri': 'spotify:track:7brHKGKFdRhzReovMw1T8z',
#    'track_href': 'https://api.spotify.com/v1/tracks/7brHKGKFdRhzReovMw1T8z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7brHKGKFdRhzReovMw1T8z',
#    'duration_ms': 274400,
#    'time_signature': 4},
#   {'danceability': 0.292,
#    'energy': 0.927,
#    'key': 7,
#    'loudness': -5.142,
#    'mode': 0,
#    'speechiness': 0.081,
#    'acousticness': 0.000126,
#    'instrumentalness': 0.0417,
#    'liveness': 0.178,
#    'valence': 0.403,
#    'tempo': 92.236,
#    'type': 'audio_features',
#    'id': '2eHruBEy06Vt7VswO4ROhC',
#    'uri': 'spotify:track:2eHruBEy06Vt7VswO4ROhC',
#    'track_href': 'https://api.spotify.com/v1/tracks/2eHruBEy06Vt7VswO4ROhC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2eHruBEy06Vt7VswO4ROhC',
#    'duration_ms': 190800,
#    'time_signature': 4},
#   {'danceability': 0.259,
#    'energy': 0.916,
#    'key': 7,
#    'loudness': -5.481,
#    'mode': 1,
#    'speechiness': 0.0841,
#    'acousticness': 0.000751,
#    'instrumentalness': 0.017,
#    'liveness': 0.0639,
#    'valence': 0.21,
#    'tempo': 146.355,
#    'type': 'audio_features',
#    'id': '4UDyPXAzvzsNNjKNNdCGmp',
#    'uri': 'spotify:track:4UDyPXAzvzsNNjKNNdCGmp',
#    'track_href': 'https://api.spotify.com/v1/tracks/4UDyPXAzvzsNNjKNNdCGmp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4UDyPXAzvzsNNjKNNdCGmp',
#    'duration_ms': 302000,
#    'time_signature': 4},
#   {'danceability': 0.481,
#    'energy': 0.242,
#    'key': 0,
#    'loudness': -11.81,
#    'mode': 1,
#    'speechiness': 0.0373,
#    'acousticness': 0.493,
#    'instrumentalness': 0,
#    'liveness': 0.137,
#    'valence': 0.389,
#    'tempo': 116.342,
#    'type': 'audio_features',
#    'id': '3BTsv0FthgmDwyKlYShwJF',
#    'uri': 'spotify:track:3BTsv0FthgmDwyKlYShwJF',
#    'track_href': 'https://api.spotify.com/v1/tracks/3BTsv0FthgmDwyKlYShwJF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BTsv0FthgmDwyKlYShwJF',
#    'duration_ms': 173240,
#    'time_signature': 4},
#   {'danceability': 0.599,
#    'energy': 0.613,
#    'key': 11,
#    'loudness': -8.643,
#    'mode': 1,
#    'speechiness': 0.0391,
#    'acousticness': 0.312,
#    'instrumentalness': 0.000355,
#    'liveness': 0.3,
#    'valence': 0.834,
#    'tempo': 124.171,
#    'type': 'audio_features',
#    'id': '5tCjWV0DA1BXd2vs4UwF2z',
#    'uri': 'spotify:track:5tCjWV0DA1BXd2vs4UwF2z',
#    'track_href': 'https://api.spotify.com/v1/tracks/5tCjWV0DA1BXd2vs4UwF2z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5tCjWV0DA1BXd2vs4UwF2z',
#    'duration_ms': 139733,
#    'time_signature': 4},
#   {'danceability': 0.412,
#    'energy': 0.658,
#    'key': 4,
#    'loudness': -12.051,
#    'mode': 0,
#    'speechiness': 0.0708,
#    'acousticness': 4.52e-05,
#    'instrumentalness': 0.000774,
#    'liveness': 0.176,
#    'valence': 0.454,
#    'tempo': 163.071,
#    'type': 'audio_features',
#    'id': '1Y373MqadDRtclJNdnUXVc',
#    'uri': 'spotify:track:1Y373MqadDRtclJNdnUXVc',
#    'track_href': 'https://api.spotify.com/v1/tracks/1Y373MqadDRtclJNdnUXVc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Y373MqadDRtclJNdnUXVc',
#    'duration_ms': 168406,
#    'time_signature': 4}],
#  [{'danceability': 0.239,
#    'energy': 0.754,
#    'key': 0,
#    'loudness': -6.645,
#    'mode': 1,
#    'speechiness': 0.0354,
#    'acousticness': 0.000131,
#    'instrumentalness': 0.000491,
#    'liveness': 0.333,
#    'valence': 0.478,
#    'tempo': 82.663,
#    'type': 'audio_features',
#    'id': '5FAO8M86HZX9TFfBMR2isb',
#    'uri': 'spotify:track:5FAO8M86HZX9TFfBMR2isb',
#    'track_href': 'https://api.spotify.com/v1/tracks/5FAO8M86HZX9TFfBMR2isb',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FAO8M86HZX9TFfBMR2isb',
#    'duration_ms': 378920,
#    'time_signature': 4},
#   {'danceability': 0.668,
#    'energy': 0.605,
#    'key': 2,
#    'loudness': -7.608,
#    'mode': 0,
#    'speechiness': 0.0454,
#    'acousticness': 0.336,
#    'instrumentalness': 0.000206,
#    'liveness': 0.115,
#    'valence': 0.877,
#    'tempo': 83.002,
#    'type': 'audio_features',
#    'id': '384TJj6XyHUyNlCbdgm6Sz',
#    'uri': 'spotify:track:384TJj6XyHUyNlCbdgm6Sz',
#    'track_href': 'https://api.spotify.com/v1/tracks/384TJj6XyHUyNlCbdgm6Sz',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/384TJj6XyHUyNlCbdgm6Sz',
#    'duration_ms': 245995,
#    'time_signature': 4},
#   {'danceability': 0.705,
#    'energy': 0.728,
#    'key': 4,
#    'loudness': -3.184,
#    'mode': 0,
#    'speechiness': 0.035,
#    'acousticness': 0.00122,
#    'instrumentalness': 0.0693,
#    'liveness': 0.0753,
#    'valence': 0.966,
#    'tempo': 109.991,
#    'type': 'audio_features',
#    'id': '4Y6GIje3GErVRIq1Ff5BJq',
#    'uri': 'spotify:track:4Y6GIje3GErVRIq1Ff5BJq',
#    'track_href': 'https://api.spotify.com/v1/tracks/4Y6GIje3GErVRIq1Ff5BJq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Y6GIje3GErVRIq1Ff5BJq',
#    'duration_ms': 226533,
#    'time_signature': 4},
#   {'danceability': 0.513,
#    'energy': 0.168,
#    'key': 0,
#    'loudness': -13.937,
#    'mode': 1,
#    'speechiness': 0.0351,
#    'acousticness': 0.785,
#    'instrumentalness': 0,
#    'liveness': 0.222,
#    'valence': 0.666,
#    'tempo': 115.647,
#    'type': 'audio_features',
#    'id': '5ubfR5Biqx3Mh9lYK0Davt',
#    'uri': 'spotify:track:5ubfR5Biqx3Mh9lYK0Davt',
#    'track_href': 'https://api.spotify.com/v1/tracks/5ubfR5Biqx3Mh9lYK0Davt',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ubfR5Biqx3Mh9lYK0Davt',
#    'duration_ms': 284680,
#    'time_signature': 3},
#   {'danceability': 0.5,
#    'energy': 0.824,
#    'key': 4,
#    'loudness': -5.846,
#    'mode': 0,
#    'speechiness': 0.0388,
#    'acousticness': 0.00016,
#    'instrumentalness': 0.00161,
#    'liveness': 0.0916,
#    'valence': 0.539,
#    'tempo': 120.125,
#    'type': 'audio_features',
#    'id': '4P5KoWXOxwuobLmHXLMobV',
#    'uri': 'spotify:track:4P5KoWXOxwuobLmHXLMobV',
#    'track_href': 'https://api.spotify.com/v1/tracks/4P5KoWXOxwuobLmHXLMobV',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4P5KoWXOxwuobLmHXLMobV',
#    'duration_ms': 218920,
#    'time_signature': 4},
#   {'danceability': 0.369,
#    'energy': 0.21,
#    'key': 6,
#    'loudness': -13.552,
#    'mode': 1,
#    'speechiness': 0.0437,
#    'acousticness': 0.959,
#    'instrumentalness': 4.53e-05,
#    'liveness': 0.0905,
#    'valence': 0.391,
#    'tempo': 131.714,
#    'type': 'audio_features',
#    'id': '25ZYvZ2qFw7XCu8nzUxxmU',
#    'uri': 'spotify:track:25ZYvZ2qFw7XCu8nzUxxmU',
#    'track_href': 'https://api.spotify.com/v1/tracks/25ZYvZ2qFw7XCu8nzUxxmU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25ZYvZ2qFw7XCu8nzUxxmU',
#    'duration_ms': 142173,
#    'time_signature': 3},
#   {'danceability': 0.637,
#    'energy': 0.69,
#    'key': 1,
#    'loudness': -4.057,
#    'mode': 0,
#    'speechiness': 0.0405,
#    'acousticness': 0.00786,
#    'instrumentalness': 0,
#    'liveness': 0.124,
#    'valence': 0.457,
#    'tempo': 129.857,
#    'type': 'audio_features',
#    'id': '7a53HqqArd4b9NF4XAmlbI',
#    'uri': 'spotify:track:7a53HqqArd4b9NF4XAmlbI',
#    'track_href': 'https://api.spotify.com/v1/tracks/7a53HqqArd4b9NF4XAmlbI',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7a53HqqArd4b9NF4XAmlbI',
#    'duration_ms': 162399,
#    'time_signature': 4},
#   {'danceability': 0.558,
#    'energy': 0.364,
#    'key': 4,
#    'loudness': -11.258,
#    'mode': 0,
#    'speechiness': 0.0265,
#    'acousticness': 0.0505,
#    'instrumentalness': 5.02e-06,
#    'liveness': 0.0753,
#    'valence': 0.17,
#    'tempo': 142.171,
#    'type': 'audio_features',
#    'id': '10igKaIKsSB6ZnWxPxPvKO',
#    'uri': 'spotify:track:10igKaIKsSB6ZnWxPxPvKO',
#    'track_href': 'https://api.spotify.com/v1/tracks/10igKaIKsSB6ZnWxPxPvKO',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10igKaIKsSB6ZnWxPxPvKO',
#    'duration_ms': 388733,
#    'time_signature': 3},
#   {'danceability': 0.688,
#    'energy': 0.879,
#    'key': 7,
#    'loudness': -5.231,
#    'mode': 1,
#    'speechiness': 0.2,
#    'acousticness': 0.624,
#    'instrumentalness': 0,
#    'liveness': 0.173,
#    'valence': 0.265,
#    'tempo': 124.904,
#    'type': 'audio_features',
#    'id': '6my3pKZ8QxxI5ZezQVR0wf',
#    'uri': 'spotify:track:6my3pKZ8QxxI5ZezQVR0wf',
#    'track_href': 'https://api.spotify.com/v1/tracks/6my3pKZ8QxxI5ZezQVR0wf',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6my3pKZ8QxxI5ZezQVR0wf',
#    'duration_ms': 205027,
#    'time_signature': 4},
#   {'danceability': 0.83,
#    'energy': 0.78,
#    'key': 5,
#    'loudness': -4.298,
#    'mode': 1,
#    'speechiness': 0.0334,
#    'acousticness': 0.154,
#    'instrumentalness': 0.3,
#    'liveness': 0.31,
#    'valence': 0.959,
#    'tempo': 159.8,
#    'type': 'audio_features',
#    'id': '1HwDNMcsD0XC6VXvvptdXq',
#    'uri': 'spotify:track:1HwDNMcsD0XC6VXvvptdXq',
#    'track_href': 'https://api.spotify.com/v1/tracks/1HwDNMcsD0XC6VXvvptdXq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HwDNMcsD0XC6VXvvptdXq',
#    'duration_ms': 36000,
#    'time_signature': 4},
#   {'danceability': 0.504,
#    'energy': 0.0615,
#    'key': 7,
#    'loudness': -12.092,
#    'mode': 1,
#    'speechiness': 0.0668,
#    'acousticness': 0.801,
#    'instrumentalness': 0.779,
#    'liveness': 0.0422,
#    'valence': 0.334,
#    'tempo': 157.888,
#    'type': 'audio_features',
#    'id': '4rJbK6vMdh3cw7UcjvKA67',
#    'uri': 'spotify:track:4rJbK6vMdh3cw7UcjvKA67',
#    'track_href': 'https://api.spotify.com/v1/tracks/4rJbK6vMdh3cw7UcjvKA67',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4rJbK6vMdh3cw7UcjvKA67',
#    'duration_ms': 163368,
#    'time_signature': 3},
#   {'danceability': 0.816,
#    'energy': 0.894,
#    'key': 6,
#    'loudness': -9.243,
#    'mode': 1,
#    'speechiness': 0.0817,
#    'acousticness': 0.0226,
#    'instrumentalness': 7.23e-05,
#    'liveness': 0.331,
#    'valence': 0.968,
#    'tempo': 99.995,
#    'type': 'audio_features',
#    'id': '3z2aHQwr9MJ5g7DA19tpha',
#    'uri': 'spotify:track:3z2aHQwr9MJ5g7DA19tpha',
#    'track_href': 'https://api.spotify.com/v1/tracks/3z2aHQwr9MJ5g7DA19tpha',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3z2aHQwr9MJ5g7DA19tpha',
#    'duration_ms': 222920,
#    'time_signature': 4},
#   {'danceability': 0.505,
#    'energy': 0.917,
#    'key': 3,
#    'loudness': -4.435,
#    'mode': 1,
#    'speechiness': 0.164,
#    'acousticness': 0.00293,
#    'instrumentalness': 0.00396,
#    'liveness': 0.204,
#    'valence': 0.39,
#    'tempo': 124.953,
#    'type': 'audio_features',
#    'id': '4LimlSNYAlc5TMCi32Yuy8',
#    'uri': 'spotify:track:4LimlSNYAlc5TMCi32Yuy8',
#    'track_href': 'https://api.spotify.com/v1/tracks/4LimlSNYAlc5TMCi32Yuy8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LimlSNYAlc5TMCi32Yuy8',
#    'duration_ms': 204517,
#    'time_signature': 4},
#   {'danceability': 0.41,
#    'energy': 0.943,
#    'key': 8,
#    'loudness': -6.991,
#    'mode': 1,
#    'speechiness': 0.0456,
#    'acousticness': 2.51e-05,
#    'instrumentalness': 0.00319,
#    'liveness': 0.207,
#    'valence': 0.675,
#    'tempo': 133.513,
#    'type': 'audio_features',
#    'id': '0GMnES4HiZpPOAham6DiH9',
#    'uri': 'spotify:track:0GMnES4HiZpPOAham6DiH9',
#    'track_href': 'https://api.spotify.com/v1/tracks/0GMnES4HiZpPOAham6DiH9',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0GMnES4HiZpPOAham6DiH9',
#    'duration_ms': 262773,
#    'time_signature': 4},
#   {'danceability': 0.461,
#    'energy': 0.168,
#    'key': 11,
#    'loudness': -16.225,
#    'mode': 0,
#    'speechiness': 0.042,
#    'acousticness': 0.449,
#    'instrumentalness': 0.886,
#    'liveness': 0.265,
#    'valence': 0.309,
#    'tempo': 169.675,
#    'type': 'audio_features',
#    'id': '3iYermCTDOt4YfeCqf3sIn',
#    'uri': 'spotify:track:3iYermCTDOt4YfeCqf3sIn',
#    'track_href': 'https://api.spotify.com/v1/tracks/3iYermCTDOt4YfeCqf3sIn',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3iYermCTDOt4YfeCqf3sIn',
#    'duration_ms': 422464,
#    'time_signature': 4},
#   {'danceability': 0.621,
#    'energy': 0.873,
#    'key': 5,
#    'loudness': -3.067,
#    'mode': 0,
#    'speechiness': 0.0369,
#    'acousticness': 0.0406,
#    'instrumentalness': 9.1e-06,
#    'liveness': 0.0824,
#    'valence': 0.873,
#    'tempo': 97.96,
#    'type': 'audio_features',
#    'id': '5hM5arv9KDbCHS0k9uqwjr',
#    'uri': 'spotify:track:5hM5arv9KDbCHS0k9uqwjr',
#    'track_href': 'https://api.spotify.com/v1/tracks/5hM5arv9KDbCHS0k9uqwjr',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5hM5arv9KDbCHS0k9uqwjr',
#    'duration_ms': 237800,
#    'time_signature': 4},
#   {'danceability': 0.634,
#    'energy': 0.838,
#    'key': 2,
#    'loudness': -5.363,
#    'mode': 1,
#    'speechiness': 0.0413,
#    'acousticness': 0.0531,
#    'instrumentalness': 8.34e-06,
#    'liveness': 0.0522,
#    'valence': 0.541,
#    'tempo': 95.011,
#    'type': 'audio_features',
#    'id': '79LdvxXi5JYUjhnO7v9Fi3',
#    'uri': 'spotify:track:79LdvxXi5JYUjhnO7v9Fi3',
#    'track_href': 'https://api.spotify.com/v1/tracks/79LdvxXi5JYUjhnO7v9Fi3',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/79LdvxXi5JYUjhnO7v9Fi3',
#    'duration_ms': 237320,
#    'time_signature': 4},
#   {'danceability': 0.696,
#    'energy': 0.758,
#    'key': 4,
#    'loudness': -6.076,
#    'mode': 1,
#    'speechiness': 0.0264,
#    'acousticness': 0.17,
#    'instrumentalness': 3.33e-05,
#    'liveness': 0.189,
#    'valence': 0.859,
#    'tempo': 129.943,
#    'type': 'audio_features',
#    'id': '3b1IQflSLrgzYQPGFzI9cl',
#    'uri': 'spotify:track:3b1IQflSLrgzYQPGFzI9cl',
#    'track_href': 'https://api.spotify.com/v1/tracks/3b1IQflSLrgzYQPGFzI9cl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3b1IQflSLrgzYQPGFzI9cl',
#    'duration_ms': 250693,
#    'time_signature': 4},
#   {'danceability': 0.752,
#    'energy': 0.529,
#    'key': 1,
#    'loudness': -5.842,
#    'mode': 0,
#    'speechiness': 0.369,
#    'acousticness': 0.31,
#    'instrumentalness': 0,
#    'liveness': 0.0875,
#    'valence': 0.643,
#    'tempo': 89.249,
#    'type': 'audio_features',
#    'id': '71oz9Wgbrm873aMlVBrDKR',
#    'uri': 'spotify:track:71oz9Wgbrm873aMlVBrDKR',
#    'track_href': 'https://api.spotify.com/v1/tracks/71oz9Wgbrm873aMlVBrDKR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/71oz9Wgbrm873aMlVBrDKR',
#    'duration_ms': 198253,
#    'time_signature': 4},
#   {'danceability': 0.31,
#    'energy': 0.277,
#    'key': 7,
#    'loudness': -14.631,
#    'mode': 1,
#    'speechiness': 0.0551,
#    'acousticness': 0.957,
#    'instrumentalness': 0.259,
#    'liveness': 0.0676,
#    'valence': 0.114,
#    'tempo': 137.618,
#    'type': 'audio_features',
#    'id': '21lSGYiCTr3ZuCgub1DF7H',
#    'uri': 'spotify:track:21lSGYiCTr3ZuCgub1DF7H',
#    'track_href': 'https://api.spotify.com/v1/tracks/21lSGYiCTr3ZuCgub1DF7H',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21lSGYiCTr3ZuCgub1DF7H',
#    'duration_ms': 269827,
#    'time_signature': 3},
#   {'danceability': 0.616,
#    'energy': 0.702,
#    'key': 10,
#    'loudness': -8.467,
#    'mode': 0,
#    'speechiness': 0.0618,
#    'acousticness': 0.00321,
#    'instrumentalness': 0,
#    'liveness': 0.391,
#    'valence': 0.41,
#    'tempo': 78.728,
#    'type': 'audio_features',
#    'id': '4dxaWUoxT0PNbs9udjSutU',
#    'uri': 'spotify:track:4dxaWUoxT0PNbs9udjSutU',
#    'track_href': 'https://api.spotify.com/v1/tracks/4dxaWUoxT0PNbs9udjSutU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dxaWUoxT0PNbs9udjSutU',
#    'duration_ms': 135973,
#    'time_signature': 4},
#   {'danceability': 0.659,
#    'energy': 0.502,
#    'key': 11,
#    'loudness': -7.809,
#    'mode': 0,
#    'speechiness': 0.033,
#    'acousticness': 0.701,
#    'instrumentalness': 3.53e-06,
#    'liveness': 0.117,
#    'valence': 0.427,
#    'tempo': 93.41,
#    'type': 'audio_features',
#    'id': '0LweSmBgZ0oY6mKCkvgdRU',
#    'uri': 'spotify:track:0LweSmBgZ0oY6mKCkvgdRU',
#    'track_href': 'https://api.spotify.com/v1/tracks/0LweSmBgZ0oY6mKCkvgdRU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LweSmBgZ0oY6mKCkvgdRU',
#    'duration_ms': 173733,
#    'time_signature': 4},
#   {'danceability': 0.709,
#    'energy': 0.787,
#    'key': 9,
#    'loudness': -6.3,
#    'mode': 1,
#    'speechiness': 0.0279,
#    'acousticness': 0.0891,
#    'instrumentalness': 0,
#    'liveness': 0.149,
#    'valence': 0.874,
#    'tempo': 118.001,
#    'type': 'audio_features',
#    'id': '0ZAJ660VP57lLK4U7NlGOy',
#    'uri': 'spotify:track:0ZAJ660VP57lLK4U7NlGOy',
#    'track_href': 'https://api.spotify.com/v1/tracks/0ZAJ660VP57lLK4U7NlGOy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ZAJ660VP57lLK4U7NlGOy',
#    'duration_ms': 260371,
#    'time_signature': 4},
#   {'danceability': 0.235,
#    'energy': 0.92,
#    'key': 1,
#    'loudness': -5.124,
#    'mode': 0,
#    'speechiness': 0.071,
#    'acousticness': 0.0269,
#    'instrumentalness': 0.814,
#    'liveness': 0.231,
#    'valence': 0.552,
#    'tempo': 95.076,
#    'type': 'audio_features',
#    'id': '0Af99n8xtgGe57zDumMcOT',
#    'uri': 'spotify:track:0Af99n8xtgGe57zDumMcOT',
#    'track_href': 'https://api.spotify.com/v1/tracks/0Af99n8xtgGe57zDumMcOT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Af99n8xtgGe57zDumMcOT',
#    'duration_ms': 435213,
#    'time_signature': 4},
#   {'danceability': 0.7,
#    'energy': 0.264,
#    'key': 7,
#    'loudness': -16.535,
#    'mode': 1,
#    'speechiness': 0.0366,
#    'acousticness': 0.835,
#    'instrumentalness': 0.00253,
#    'liveness': 0.115,
#    'valence': 0.55,
#    'tempo': 126.015,
#    'type': 'audio_features',
#    'id': '6ZznUaja8PfIbU7UPUJrj4',
#    'uri': 'spotify:track:6ZznUaja8PfIbU7UPUJrj4',
#    'track_href': 'https://api.spotify.com/v1/tracks/6ZznUaja8PfIbU7UPUJrj4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ZznUaja8PfIbU7UPUJrj4',
#    'duration_ms': 260524,
#    'time_signature': 4},
#   {'danceability': 0.716,
#    'energy': 0.563,
#    'key': 5,
#    'loudness': -10.418,
#    'mode': 0,
#    'speechiness': 0.133,
#    'acousticness': 0.558,
#    'instrumentalness': 7.41e-06,
#    'liveness': 0.0454,
#    'valence': 0.717,
#    'tempo': 90.082,
#    'type': 'audio_features',
#    'id': '5LHqxKauqQUsZeDKwllkmf',
#    'uri': 'spotify:track:5LHqxKauqQUsZeDKwllkmf',
#    'track_href': 'https://api.spotify.com/v1/tracks/5LHqxKauqQUsZeDKwllkmf',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5LHqxKauqQUsZeDKwllkmf',
#    'duration_ms': 239613,
#    'time_signature': 4},
#   {'danceability': 0.344,
#    'energy': 0.881,
#    'key': 11,
#    'loudness': -4.643,
#    'mode': 0,
#    'speechiness': 0.0792,
#    'acousticness': 0.15,
#    'instrumentalness': 0.435,
#    'liveness': 0.126,
#    'valence': 0.415,
#    'tempo': 89.664,
#    'type': 'audio_features',
#    'id': '3Q3Cs0yBnPIGS9HyCgkJoL',
#    'uri': 'spotify:track:3Q3Cs0yBnPIGS9HyCgkJoL',
#    'track_href': 'https://api.spotify.com/v1/tracks/3Q3Cs0yBnPIGS9HyCgkJoL',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Q3Cs0yBnPIGS9HyCgkJoL',
#    'duration_ms': 544840,
#    'time_signature': 4},
#   {'danceability': 0.682,
#    'energy': 0.752,
#    'key': 2,
#    'loudness': -9.521,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.476,
#    'instrumentalness': 0.863,
#    'liveness': 0.0768,
#    'valence': 0.964,
#    'tempo': 81.081,
#    'type': 'audio_features',
#    'id': '1m3BAsNsQAaSNMD2M6vlKY',
#    'uri': 'spotify:track:1m3BAsNsQAaSNMD2M6vlKY',
#    'track_href': 'https://api.spotify.com/v1/tracks/1m3BAsNsQAaSNMD2M6vlKY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1m3BAsNsQAaSNMD2M6vlKY',
#    'duration_ms': 341733,
#    'time_signature': 4},
#   {'danceability': 0.722,
#    'energy': 0.893,
#    'key': 0,
#    'loudness': -3.255,
#    'mode': 0,
#    'speechiness': 0.0475,
#    'acousticness': 0.0441,
#    'instrumentalness': 0.000937,
#    'liveness': 0.0673,
#    'valence': 0.439,
#    'tempo': 119.932,
#    'type': 'audio_features',
#    'id': '3iw6V4LH7yPj1ESORX9RIN',
#    'uri': 'spotify:track:3iw6V4LH7yPj1ESORX9RIN',
#    'track_href': 'https://api.spotify.com/v1/tracks/3iw6V4LH7yPj1ESORX9RIN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3iw6V4LH7yPj1ESORX9RIN',
#    'duration_ms': 116750,
#    'time_signature': 4},
#   {'danceability': 0.656,
#    'energy': 0.659,
#    'key': 7,
#    'loudness': -13.286,
#    'mode': 1,
#    'speechiness': 0.0506,
#    'acousticness': 0.000269,
#    'instrumentalness': 0.776,
#    'liveness': 0.234,
#    'valence': 0.615,
#    'tempo': 126.931,
#    'type': 'audio_features',
#    'id': '5VfHsPUO9aLEN73bvfrJbJ',
#    'uri': 'spotify:track:5VfHsPUO9aLEN73bvfrJbJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/5VfHsPUO9aLEN73bvfrJbJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5VfHsPUO9aLEN73bvfrJbJ',
#    'duration_ms': 180427,
#    'time_signature': 4},
#   {'danceability': 0.533,
#    'energy': 0.905,
#    'key': 2,
#    'loudness': -5.27,
#    'mode': 1,
#    'speechiness': 0.0754,
#    'acousticness': 0.00876,
#    'instrumentalness': 0.578,
#    'liveness': 0.0698,
#    'valence': 0.486,
#    'tempo': 108.9,
#    'type': 'audio_features',
#    'id': '0wJoRiX5K5BxlqZTolB2LD',
#    'uri': 'spotify:track:0wJoRiX5K5BxlqZTolB2LD',
#    'track_href': 'https://api.spotify.com/v1/tracks/0wJoRiX5K5BxlqZTolB2LD',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0wJoRiX5K5BxlqZTolB2LD',
#    'duration_ms': 170813,
#    'time_signature': 4},
#   {'danceability': 0.665,
#    'energy': 0.852,
#    'key': 9,
#    'loudness': -3.252,
#    'mode': 0,
#    'speechiness': 0.0331,
#    'acousticness': 0.00338,
#    'instrumentalness': 4.16e-05,
#    'liveness': 0.151,
#    'valence': 0.952,
#    'tempo': 120.044,
#    'type': 'audio_features',
#    'id': '4wjbUTC312rQO7rziAONDa',
#    'uri': 'spotify:track:4wjbUTC312rQO7rziAONDa',
#    'track_href': 'https://api.spotify.com/v1/tracks/4wjbUTC312rQO7rziAONDa',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wjbUTC312rQO7rziAONDa',
#    'duration_ms': 238507,
#    'time_signature': 4},
#   {'danceability': 0.349,
#    'energy': 0.0636,
#    'key': 8,
#    'loudness': -23.599,
#    'mode': 1,
#    'speechiness': 0.0379,
#    'acousticness': 0.991,
#    'instrumentalness': 0.857,
#    'liveness': 0.0838,
#    'valence': 0.107,
#    'tempo': 124.171,
#    'type': 'audio_features',
#    'id': '3Tlf69FTufTsWT9rsXiW4b',
#    'uri': 'spotify:track:3Tlf69FTufTsWT9rsXiW4b',
#    'track_href': 'https://api.spotify.com/v1/tracks/3Tlf69FTufTsWT9rsXiW4b',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Tlf69FTufTsWT9rsXiW4b',
#    'duration_ms': 169747,
#    'time_signature': 4},
#   {'danceability': 0.545,
#    'energy': 0.865,
#    'key': 11,
#    'loudness': -5.708,
#    'mode': 0,
#    'speechiness': 0.0286,
#    'acousticness': 0.00664,
#    'instrumentalness': 1.1e-05,
#    'liveness': 0.168,
#    'valence': 0.543,
#    'tempo': 99.009,
#    'type': 'audio_features',
#    'id': '6ZOBP3NvffbU4SZcrnt1k6',
#    'uri': 'spotify:track:6ZOBP3NvffbU4SZcrnt1k6',
#    'track_href': 'https://api.spotify.com/v1/tracks/6ZOBP3NvffbU4SZcrnt1k6',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ZOBP3NvffbU4SZcrnt1k6',
# ...
#    'energy': 0.946,
#    'key': 2,
#    'loudness': -3.567,
#    'mode': 1,
#    'speechiness': 0.0615,
#    'acousticness': 0.107,
#    'instrumentalness': 0.000663,
#    'liveness': 0.234,
#    'valence': 0.708,
#    'tempo': 86.968,
#    'type': 'audio_features',
#    'id': '5dQMObs42MjoeCy26cyQ0a',
#    'uri': 'spotify:track:5dQMObs42MjoeCy26cyQ0a',
#    'track_href': 'https://api.spotify.com/v1/tracks/5dQMObs42MjoeCy26cyQ0a',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dQMObs42MjoeCy26cyQ0a',
#    'duration_ms': 172813,
#    'time_signature': 3},
#   {'danceability': 0.721,
#    'energy': 0.674,
#    'key': 5,
#    'loudness': -9.075,
#    'mode': 0,
#    'speechiness': 0.0884,
#    'acousticness': 0.765,
#    'instrumentalness': 1.42e-05,
#    'liveness': 0.082,
#    'valence': 0.77,
#    'tempo': 109.045,
#    'type': 'audio_features',
#    'id': '6QuxbllapSfqVCA33PdhpS',
#    'uri': 'spotify:track:6QuxbllapSfqVCA33PdhpS',
#    'track_href': 'https://api.spotify.com/v1/tracks/6QuxbllapSfqVCA33PdhpS',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QuxbllapSfqVCA33PdhpS',
#    'duration_ms': 222280,
#    'time_signature': 4},
#   {'danceability': 0.495,
#    'energy': 0.941,
#    'key': 6,
#    'loudness': -4.891,
#    'mode': 1,
#    'speechiness': 0.0651,
#    'acousticness': 0.131,
#    'instrumentalness': 0.835,
#    'liveness': 0.128,
#    'valence': 0.494,
#    'tempo': 107.713,
#    'type': 'audio_features',
#    'id': '0KJAdjLV940uCtKC3qyK1q',
#    'uri': 'spotify:track:0KJAdjLV940uCtKC3qyK1q',
#    'track_href': 'https://api.spotify.com/v1/tracks/0KJAdjLV940uCtKC3qyK1q',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KJAdjLV940uCtKC3qyK1q',
#    'duration_ms': 404400,
#    'time_signature': 3},
#   {'danceability': 0.608,
#    'energy': 0.578,
#    'key': 5,
#    'loudness': -6.764,
#    'mode': 0,
#    'speechiness': 0.0951,
#    'acousticness': 0.506,
#    'instrumentalness': 3.58e-05,
#    'liveness': 0.28,
#    'valence': 0.745,
#    'tempo': 133.069,
#    'type': 'audio_features',
#    'id': '6QZ4ZhD8hGVTfwoN2Ypl4Z',
#    'uri': 'spotify:track:6QZ4ZhD8hGVTfwoN2Ypl4Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/6QZ4ZhD8hGVTfwoN2Ypl4Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QZ4ZhD8hGVTfwoN2Ypl4Z',
#    'duration_ms': 162080,
#    'time_signature': 1},
#   {'danceability': 0.556,
#    'energy': 0.258,
#    'key': 5,
#    'loudness': -11.745,
#    'mode': 1,
#    'speechiness': 0.0412,
#    'acousticness': 0.698,
#    'instrumentalness': 5.56e-05,
#    'liveness': 0.0954,
#    'valence': 0.414,
#    'tempo': 83.964,
#    'type': 'audio_features',
#    'id': '3BF3uROPt95X3X7ZixXFRC',
#    'uri': 'spotify:track:3BF3uROPt95X3X7ZixXFRC',
#    'track_href': 'https://api.spotify.com/v1/tracks/3BF3uROPt95X3X7ZixXFRC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BF3uROPt95X3X7ZixXFRC',
#    'duration_ms': 317987,
#    'time_signature': 4},
#   {'danceability': 0.749,
#    'energy': 0.359,
#    'key': 11,
#    'loudness': -12.749,
#    'mode': 0,
#    'speechiness': 0.0415,
#    'acousticness': 0.664,
#    'instrumentalness': 1.34e-05,
#    'liveness': 0.0871,
#    'valence': 0.523,
#    'tempo': 105.982,
#    'type': 'audio_features',
#    'id': '3EissuXjQZQrjpHh8gRCG1',
#    'uri': 'spotify:track:3EissuXjQZQrjpHh8gRCG1',
#    'track_href': 'https://api.spotify.com/v1/tracks/3EissuXjQZQrjpHh8gRCG1',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3EissuXjQZQrjpHh8gRCG1',
#    'duration_ms': 286240,
#    'time_signature': 4},
#   {'danceability': 0.659,
#    'energy': 0.635,
#    'key': 10,
#    'loudness': -10.569,
#    'mode': 0,
#    'speechiness': 0.202,
#    'acousticness': 0.603,
#    'instrumentalness': 0.0214,
#    'liveness': 0.172,
#    'valence': 0.413,
#    'tempo': 144.965,
#    'type': 'audio_features',
#    'id': '4oarDDCWsSnX2WOIRKuQo1',
#    'uri': 'spotify:track:4oarDDCWsSnX2WOIRKuQo1',
#    'track_href': 'https://api.spotify.com/v1/tracks/4oarDDCWsSnX2WOIRKuQo1',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4oarDDCWsSnX2WOIRKuQo1',
#    'duration_ms': 177867,
#    'time_signature': 4},
#   {'danceability': 0.439,
#    'energy': 0.922,
#    'key': 2,
#    'loudness': -7.927,
#    'mode': 1,
#    'speechiness': 0.0394,
#    'acousticness': 0.064,
#    'instrumentalness': 0.00278,
#    'liveness': 0.907,
#    'valence': 0.563,
#    'tempo': 148.585,
#    'type': 'audio_features',
#    'id': '2hiUfCxHe1yjRFLwaXdQtH',
#    'uri': 'spotify:track:2hiUfCxHe1yjRFLwaXdQtH',
#    'track_href': 'https://api.spotify.com/v1/tracks/2hiUfCxHe1yjRFLwaXdQtH',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2hiUfCxHe1yjRFLwaXdQtH',
#    'duration_ms': 152907,
#    'time_signature': 4},
#   {'danceability': 0.458,
#    'energy': 0.515,
#    'key': 5,
#    'loudness': -10.352,
#    'mode': 0,
#    'speechiness': 0.0452,
#    'acousticness': 0.589,
#    'instrumentalness': 0,
#    'liveness': 0.245,
#    'valence': 0.497,
#    'tempo': 137.317,
#    'type': 'audio_features',
#    'id': '38dblnB5Zf0ccrnqyv6i4R',
#    'uri': 'spotify:track:38dblnB5Zf0ccrnqyv6i4R',
#    'track_href': 'https://api.spotify.com/v1/tracks/38dblnB5Zf0ccrnqyv6i4R',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38dblnB5Zf0ccrnqyv6i4R',
#    'duration_ms': 201280,
#    'time_signature': 4},
#   {'danceability': 0.554,
#    'energy': 0.512,
#    'key': 9,
#    'loudness': -7.6,
#    'mode': 0,
#    'speechiness': 0.0237,
#    'acousticness': 0.0836,
#    'instrumentalness': 0.000332,
#    'liveness': 0.103,
#    'valence': 0.236,
#    'tempo': 89.296,
#    'type': 'audio_features',
#    'id': '6KVM6U9Wcxgjh0jDjoRDgh',
#    'uri': 'spotify:track:6KVM6U9Wcxgjh0jDjoRDgh',
#    'track_href': 'https://api.spotify.com/v1/tracks/6KVM6U9Wcxgjh0jDjoRDgh',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KVM6U9Wcxgjh0jDjoRDgh',
#    'duration_ms': 238627,
#    'time_signature': 4},
#   {'danceability': 0.728,
#    'energy': 0.663,
#    'key': 0,
#    'loudness': -8.337,
#    'mode': 1,
#    'speechiness': 0.0301,
#    'acousticness': 0.0587,
#    'instrumentalness': 0.0354,
#    'liveness': 0.103,
#    'valence': 0.964,
#    'tempo': 114.687,
#    'type': 'audio_features',
#    'id': '5q9xzoWQKaoYlOxJsnEX0t',
#    'uri': 'spotify:track:5q9xzoWQKaoYlOxJsnEX0t',
#    'track_href': 'https://api.spotify.com/v1/tracks/5q9xzoWQKaoYlOxJsnEX0t',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5q9xzoWQKaoYlOxJsnEX0t',
#    'duration_ms': 200067,
#    'time_signature': 4},
#   {'danceability': 0.133,
#    'energy': 0.0297,
#    'key': 9,
#    'loudness': -29.885,
#    'mode': 0,
#    'speechiness': 0.044,
#    'acousticness': 0.98,
#    'instrumentalness': 0.956,
#    'liveness': 0.0906,
#    'valence': 0.0322,
#    'tempo': 88.834,
#    'type': 'audio_features',
#    'id': '63zmiYZRPVSRLoYXbqfLPv',
#    'uri': 'spotify:track:63zmiYZRPVSRLoYXbqfLPv',
#    'track_href': 'https://api.spotify.com/v1/tracks/63zmiYZRPVSRLoYXbqfLPv',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63zmiYZRPVSRLoYXbqfLPv',
#    'duration_ms': 237794,
#    'time_signature': 1},
#   {'danceability': 0.148,
#    'energy': 0.22,
#    'key': 0,
#    'loudness': -12.867,
#    'mode': 1,
#    'speechiness': 0.0359,
#    'acousticness': 0.748,
#    'instrumentalness': 0.593,
#    'liveness': 0.15,
#    'valence': 0.0339,
#    'tempo': 85.431,
#    'type': 'audio_features',
#    'id': '7kC0m4abnB0q214TKVzDpy',
#    'uri': 'spotify:track:7kC0m4abnB0q214TKVzDpy',
#    'track_href': 'https://api.spotify.com/v1/tracks/7kC0m4abnB0q214TKVzDpy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7kC0m4abnB0q214TKVzDpy',
#    'duration_ms': 494587,
#    'time_signature': 4},
#   {'danceability': 0.263,
#    'energy': 0.706,
#    'key': 10,
#    'loudness': -6.467,
#    'mode': 1,
#    'speechiness': 0.0374,
#    'acousticness': 0.0108,
#    'instrumentalness': 0.847,
#    'liveness': 0.457,
#    'valence': 0.305,
#    'tempo': 137.381,
#    'type': 'audio_features',
#    'id': '1L5MFjEKzuq0v2xhyYWn4U',
#    'uri': 'spotify:track:1L5MFjEKzuq0v2xhyYWn4U',
#    'track_href': 'https://api.spotify.com/v1/tracks/1L5MFjEKzuq0v2xhyYWn4U',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1L5MFjEKzuq0v2xhyYWn4U',
#    'duration_ms': 501347,
#    'time_signature': 4},
#   {'danceability': 0.36,
#    'energy': 0.643,
#    'key': 7,
#    'loudness': -8.608,
#    'mode': 1,
#    'speechiness': 0.221,
#    'acousticness': 0.411,
#    'instrumentalness': 0.000241,
#    'liveness': 0.136,
#    'valence': 0.535,
#    'tempo': 81.551,
#    'type': 'audio_features',
#    'id': '5XkJj6sV2XLMaURdmdXgNx',
#    'uri': 'spotify:track:5XkJj6sV2XLMaURdmdXgNx',
#    'track_href': 'https://api.spotify.com/v1/tracks/5XkJj6sV2XLMaURdmdXgNx',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XkJj6sV2XLMaURdmdXgNx',
#    'duration_ms': 208867,
#    'time_signature': 4},
#   {'danceability': 0.506,
#    'energy': 0.378,
#    'key': 11,
#    'loudness': -16.094,
#    'mode': 0,
#    'speechiness': 0.0641,
#    'acousticness': 0.00312,
#    'instrumentalness': 0.765,
#    'liveness': 0.0556,
#    'valence': 0.476,
#    'tempo': 131.847,
#    'type': 'audio_features',
#    'id': '6MSunNFxRYhjOQR0OTuvbB',
#    'uri': 'spotify:track:6MSunNFxRYhjOQR0OTuvbB',
#    'track_href': 'https://api.spotify.com/v1/tracks/6MSunNFxRYhjOQR0OTuvbB',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6MSunNFxRYhjOQR0OTuvbB',
#    'duration_ms': 2292795,
#    'time_signature': 4},
#   {'danceability': 0.781,
#    'energy': 0.934,
#    'key': 6,
#    'loudness': -4.569,
#    'mode': 0,
#    'speechiness': 0.0465,
#    'acousticness': 0.000463,
#    'instrumentalness': 0.0102,
#    'liveness': 0.0335,
#    'valence': 0.879,
#    'tempo': 128.001,
#    'type': 'audio_features',
#    'id': '4Lm3Eh62HxFtOeY7Ra1CaI',
#    'uri': 'spotify:track:4Lm3Eh62HxFtOeY7Ra1CaI',
#    'track_href': 'https://api.spotify.com/v1/tracks/4Lm3Eh62HxFtOeY7Ra1CaI',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Lm3Eh62HxFtOeY7Ra1CaI',
#    'duration_ms': 203476,
#    'time_signature': 4},
#   {'danceability': 0.301,
#    'energy': 0.711,
#    'key': 1,
#    'loudness': -8.416,
#    'mode': 0,
#    'speechiness': 0.0388,
#    'acousticness': 0.292,
#    'instrumentalness': 0.696,
#    'liveness': 0.0805,
#    'valence': 0.798,
#    'tempo': 147.534,
#    'type': 'audio_features',
#    'id': '5p0mBhr2VBRsQE29AbbrJE',
#    'uri': 'spotify:track:5p0mBhr2VBRsQE29AbbrJE',
#    'track_href': 'https://api.spotify.com/v1/tracks/5p0mBhr2VBRsQE29AbbrJE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5p0mBhr2VBRsQE29AbbrJE',
#    'duration_ms': 250187,
#    'time_signature': 4},
#   {'danceability': 0.703,
#    'energy': 0.41,
#    'key': 3,
#    'loudness': -7.317,
#    'mode': 1,
#    'speechiness': 0.0323,
#    'acousticness': 0.473,
#    'instrumentalness': 0,
#    'liveness': 0.097,
#    'valence': 0.824,
#    'tempo': 140.08,
#    'type': 'audio_features',
#    'id': '5g1IkorHuKu1fRPWIPlkjE',
#    'uri': 'spotify:track:5g1IkorHuKu1fRPWIPlkjE',
#    'track_href': 'https://api.spotify.com/v1/tracks/5g1IkorHuKu1fRPWIPlkjE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5g1IkorHuKu1fRPWIPlkjE',
#    'duration_ms': 282769,
#    'time_signature': 4},
#   {'danceability': 0.12,
#    'energy': 0.985,
#    'key': 10,
#    'loudness': -6.733,
#    'mode': 0,
#    'speechiness': 0.123,
#    'acousticness': 1.66e-05,
#    'instrumentalness': 0.886,
#    'liveness': 0.0828,
#    'valence': 0.0749,
#    'tempo': 176.17,
#    'type': 'audio_features',
#    'id': '0qnTV9LmMYBOyzsEPNvvTR',
#    'uri': 'spotify:track:0qnTV9LmMYBOyzsEPNvvTR',
#    'track_href': 'https://api.spotify.com/v1/tracks/0qnTV9LmMYBOyzsEPNvvTR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qnTV9LmMYBOyzsEPNvvTR',
#    'duration_ms': 284040,
#    'time_signature': 4},
#   {'danceability': 0.722,
#    'energy': 0.597,
#    'key': 4,
#    'loudness': -5.964,
#    'mode': 0,
#    'speechiness': 0.0264,
#    'acousticness': 0.174,
#    'instrumentalness': 0.183,
#    'liveness': 0.181,
#    'valence': 0.389,
#    'tempo': 103.975,
#    'type': 'audio_features',
#    'id': '5pE9vMyvVNOpZFutt6lyy4',
#    'uri': 'spotify:track:5pE9vMyvVNOpZFutt6lyy4',
#    'track_href': 'https://api.spotify.com/v1/tracks/5pE9vMyvVNOpZFutt6lyy4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pE9vMyvVNOpZFutt6lyy4',
#    'duration_ms': 166482,
#    'time_signature': 4},
#   {'danceability': 0.536,
#    'energy': 0.387,
#    'key': 0,
#    'loudness': -11.655,
#    'mode': 1,
#    'speechiness': 0.126,
#    'acousticness': 0.302,
#    'instrumentalness': 0,
#    'liveness': 0.152,
#    'valence': 0.352,
#    'tempo': 82.862,
#    'type': 'audio_features',
#    'id': '4ay8z23Fa9iJgvGdbBr4Iw',
#    'uri': 'spotify:track:4ay8z23Fa9iJgvGdbBr4Iw',
#    'track_href': 'https://api.spotify.com/v1/tracks/4ay8z23Fa9iJgvGdbBr4Iw',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ay8z23Fa9iJgvGdbBr4Iw',
#    'duration_ms': 349357,
#    'time_signature': 4},
#   {'danceability': 0.173,
#    'energy': 0.969,
#    'key': 0,
#    'loudness': -4.943,
#    'mode': 0,
#    'speechiness': 0.14,
#    'acousticness': 4.8e-06,
#    'instrumentalness': 0.73,
#    'liveness': 0.11,
#    'valence': 0.368,
#    'tempo': 174.165,
#    'type': 'audio_features',
#    'id': '0e5jXSwrPPLuEr0sxm59EV',
#    'uri': 'spotify:track:0e5jXSwrPPLuEr0sxm59EV',
#    'track_href': 'https://api.spotify.com/v1/tracks/0e5jXSwrPPLuEr0sxm59EV',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0e5jXSwrPPLuEr0sxm59EV',
#    'duration_ms': 124013,
#    'time_signature': 4},
#   {'danceability': 0.269,
#    'energy': 0.238,
#    'key': 9,
#    'loudness': -15.448,
#    'mode': 0,
#    'speechiness': 0.0315,
#    'acousticness': 0.972,
#    'instrumentalness': 0.749,
#    'liveness': 0.0999,
#    'valence': 0.0343,
#    'tempo': 89.631,
#    'type': 'audio_features',
#    'id': '0I5pXnykUOC6UmGr8N6x7q',
#    'uri': 'spotify:track:0I5pXnykUOC6UmGr8N6x7q',
#    'track_href': 'https://api.spotify.com/v1/tracks/0I5pXnykUOC6UmGr8N6x7q',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0I5pXnykUOC6UmGr8N6x7q',
#    'duration_ms': 111800,
#    'time_signature': 4},
#   {'danceability': 0.578,
#    'energy': 0.793,
#    'key': 10,
#    'loudness': -6.03,
#    'mode': 1,
#    'speechiness': 0.0484,
#    'acousticness': 0.00205,
#    'instrumentalness': 0.00208,
#    'liveness': 0.0629,
#    'valence': 0.453,
#    'tempo': 123.023,
#    'type': 'audio_features',
#    'id': '0FgI8VrOH7N35LtiOBZVwA',
#    'uri': 'spotify:track:0FgI8VrOH7N35LtiOBZVwA',
#    'track_href': 'https://api.spotify.com/v1/tracks/0FgI8VrOH7N35LtiOBZVwA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0FgI8VrOH7N35LtiOBZVwA',
#    'duration_ms': 208560,
#    'time_signature': 4},
#   {'danceability': 0.149,
#    'energy': 0.859,
#    'key': 8,
#    'loudness': -3.954,
#    'mode': 1,
#    'speechiness': 0.048,
#    'acousticness': 0.109,
#    'instrumentalness': 0.00108,
#    'liveness': 0.329,
#    'valence': 0.497,
#    'tempo': 66.706,
#    'type': 'audio_features',
#    'id': '2MPlWkhbTJKXp2w1OtPS6l',
#    'uri': 'spotify:track:2MPlWkhbTJKXp2w1OtPS6l',
#    'track_href': 'https://api.spotify.com/v1/tracks/2MPlWkhbTJKXp2w1OtPS6l',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MPlWkhbTJKXp2w1OtPS6l',
#    'duration_ms': 137680,
#    'time_signature': 4},
#   {'danceability': 0.492,
#    'energy': 0.0499,
#    'key': 11,
#    'loudness': -28.814,
#    'mode': 1,
#    'speechiness': 0.0484,
#    'acousticness': 0.753,
#    'instrumentalness': 0.834,
#    'liveness': 0.139,
#    'valence': 0.631,
#    'tempo': 101.366,
#    'type': 'audio_features',
#    'id': '7f5pVscGqWGPmzyAJ3thAI',
#    'uri': 'spotify:track:7f5pVscGqWGPmzyAJ3thAI',
#    'track_href': 'https://api.spotify.com/v1/tracks/7f5pVscGqWGPmzyAJ3thAI',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7f5pVscGqWGPmzyAJ3thAI',
#    'duration_ms': 90783,
#    'time_signature': 3},
#   {'danceability': 0.0934,
#    'energy': 0.607,
#    'key': 2,
#    'loudness': -8.27,
#    'mode': 1,
#    'speechiness': 0.0389,
#    'acousticness': 9.67e-06,
#    'instrumentalness': 0.572,
#    'liveness': 0.137,
#    'valence': 0.172,
#    'tempo': 175.831,
#    'type': 'audio_features',
#    'id': '2Y2RERUaiyBH4cwWeYiJso',
#    'uri': 'spotify:track:2Y2RERUaiyBH4cwWeYiJso',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Y2RERUaiyBH4cwWeYiJso',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Y2RERUaiyBH4cwWeYiJso',
#    'duration_ms': 119347,
#    'time_signature': 3}]]

# %%
# turn audio_feats into multiple dictionaries
for i in audio_feats:
    for e in i:
        print(e)
# Out:
# {'danceability': 0.87, 'energy': 0.587, 'key': 6, 'loudness': -6.117, 'mode': 1, 'speechiness': 0.0406, 'acousticness': 0.0209, 'instrumentalness': 3.18e-06, 'liveness': 0.0888, 'valence': 0.814, 'tempo': 122.939, 'type': 'audio_features', 'id': '1FpAKPGuR8SoIUw5t0I5vn', 'uri': 'spotify:track:1FpAKPGuR8SoIUw5t0I5vn', 'track_href': 'https://api.spotify.com/v1/tracks/1FpAKPGuR8SoIUw5t0I5vn', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1
 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0FgI8VrOH7N35LtiOBZVwA', 'duration_ms': 208560, 'time_signature': 4}
# {'danceability': 0.149, 'energy': 0.859, 'key': 8, 'loudness': -3.954, 'mode': 1, 'speechiness': 0.048, 'acousticness': 0.109, 'instrumentalness': 0.00108, 'liveness': 0.329, 'valence': 0.497, 'tempo': 66.706, 'type': 'audio_features', 'id': '2MPlWkhbTJKXp2w1OtPS6l', 'uri': 'spotify:track:2MPlWkhbTJKXp2w1OtPS6l', 'track_href': 'https://api.spotify.com/v1/tracks/2MPlWkhbTJKXp2w1OtPS6l', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MPlWkhbTJKXp2w1OtPS6l', 'duration_ms': 137680, 'time_signature': 4}
# {'danceability': 0.492, 'energy': 0.0499, 'key': 11, 'loudness': -28.814, 'mode': 1, 'speechiness': 0.0484, 'acousticness': 0.753, 'instrumentalness': 0.834, 'liveness': 0.139, 'valence': 0.631, 'tempo': 101.366, 'type': 'audio_features', 'id': '7f5pVscGqWGPmzyAJ3thAI', 'uri': 'spotify:track:7f5pVscGqWGPmzyAJ3thAI', 'track_href': 'https://api.spotify.com/v1/tracks/7f5pVscGqWGPmzyAJ3thAI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7f5pVscGqWGPmzyAJ3thAI', 'duration_ms': 90783, 'time_signature': 3}
# {'danceability': 0.0934, 'energy': 0.607, 'key': 2, 'loudness': -8.27, 'mode': 1, 'speechiness': 0.0389, 'acousticness': 9.67e-06, 'instrumentalness': 0.572, 'liveness': 0.137, 'valence': 0.172, 'tempo': 175.831, 'type': 'audio_features', 'id': '2Y2RERUaiyBH4cwWeYiJso', 'uri': 'spotify:track:2Y2RERUaiyBH4cwWeYiJso', 'track_href': 'https://api.spotify.com/v1/tracks/2Y2RERUaiyBH4cwWeYiJso', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Y2RERUaiyBH4cwWeYiJso', 'duration_ms': 119347, 'time_signature': 3}

# %%
e.keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
chunk_list = [song for artist in audio_feats for song in artist if song is not None] 

# some of the value gave us problem bc they were none, thus we decided to use 'song is not none'

# %%
df = pd.DataFrame(chunk_list)
df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.8700  0.5870    6    -6.117     1       0.0406      0.020900
# 1           0.9050  0.4920    2    -8.598     1       0.0595      0.014900
# 2           0.8270  0.1890    6    -9.370     0       0.0495      0.852000
# 3           0.5020  0.9120    1    -4.556     1       0.0564      0.000025
# 4           0.2120  0.3010    2   -12.505     1       0.0384      0.963000
# ...            ...     ...  ...       ...   ...          ...           ...
# 2544        0.2690  0.2380    9   -15.448     0       0.0315      0.972000
# 2545        0.5780  0.7930   10    -6.030     1       0.0484      0.002050
# 2546        0.1490  0.8590    8    -3.954     1       0.0480      0.109000
# 2547        0.4920  0.0499   11   -28.814     1       0.0484      0.753000
# 2548        0.0934  0.6070    2    -8.270     1       0.0389      0.000010
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000003    0.0888   0.8140  122.939  audio_features
# 1             0.000038    0.3710   0.1420  110.017  audio_features
# 2             0.028000    0.1090   0.4850   88.349  audio_features
# 3             0.000173    0.1060   0.7200  116.761  audio_features
# 4             0.003300    0.1300   0.0798   84.025  audio_features
# ...                ...       ...      ...      ...             ...
# 2544          0.749000    0.0999   0.0343   89.631  audio_features
# 2545          0.002080    0.0629   0.4530  123.023  audio_features
# 2546          0.001080    0.3290   0.4970   66.706  audio_features
# 2547          0.834000    0.1390   0.6310  101.366  audio_features
# 2548          0.572000    0.1370   0.1720  175.831  audio_features
#
#                           id                                   uri  \
# 0     1FpAKPGuR8SoIUw5t0I5vn  spotify:track:1FpAKPGuR8SoIUw5t0I5vn
# 1     4v7SAP4KD96BFLWiCd1vF0  spotify:track:4v7SAP4KD96BFLWiCd1vF0
# 2     0A3JouZ9j02d15KoEzP6F0  spotify:track:0A3JouZ9j02d15KoEzP6F0
# 3     5ghIJDpPoe3CfHMGu71E6T  spotify:track:5ghIJDpPoe3CfHMGu71E6T
# 4     74WjYdm3Lvbwnds4thYPUU  spotify:track:74WjYdm3Lvbwnds4thYPUU
# ...                      ...                                   ...
# 2544  0I5pXnykUOC6UmGr8N6x7q  spotify:track:0I5pXnykUOC6UmGr8N6x7q
# 2545  0FgI8VrOH7N35LtiOBZVwA  spotify:track:0FgI8VrOH7N35LtiOBZVwA
# 2546  2MPlWkhbTJKXp2w1OtPS6l  spotify:track:2MPlWkhbTJKXp2w1OtPS6l
# 2547  7f5pVscGqWGPmzyAJ3thAI  spotify:track:7f5pVscGqWGPmzyAJ3thAI
# 2548  2Y2RERUaiyBH4cwWeYiJso  spotify:track:2Y2RERUaiyBH4cwWeYiJso
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1FpAKPGuR8So...
# 1     https://api.spotify.com/v1/tracks/4v7SAP4KD96B...
# 2     https://api.spotify.com/v1/tracks/0A3JouZ9j02d...
# 3     https://api.spotify.com/v1/tracks/5ghIJDpPoe3C...
# 4     https://api.spotify.com/v1/tracks/74WjYdm3Lvbw...
# ...                                                 ...
# 2544  https://api.spotify.com/v1/tracks/0I5pXnykUOC6...
# 2545  https://api.spotify.com/v1/tracks/0FgI8VrOH7N3...
# 2546  https://api.spotify.com/v1/tracks/2MPlWkhbTJKX...
# 2547  https://api.spotify.com/v1/tracks/7f5pVscGqWGP...
# 2548  https://api.spotify.com/v1/tracks/2Y2RERUaiyBH...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1FpA...       191073
# 1     https://api.spotify.com/v1/audio-analysis/4v7S...       177840
# 2     https://api.spotify.com/v1/audio-analysis/0A3J...       192680
# 3     https://api.spotify.com/v1/audio-analysis/5ghI...       301920
# 4     https://api.spotify.com/v1/audio-analysis/74Wj...       177333
# ...                                                 ...          ...
# 2544  https://api.spotify.com/v1/audio-analysis/0I5p...       111800
# 2545  https://api.spotify.com/v1/audio-analysis/0FgI...       208560
# 2546  https://api.spotify.com/v1/audio-analysis/2MPl...       137680
# 2547  https://api.spotify.com/v1/audio-analysis/7f5p...        90783
# 2548  https://api.spotify.com/v1/audio-analysis/2Y2R...       119347
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 2544               4
# 2545               4
# 2546               4
# 2547               3
# 2548               3
#
# [2549 rows x 18 columns]

# %%
max(df['danceability'])
# Out:
# 0.987

# %%
pwd
# Out:
# '/home/ki/Nextcloud/laboratorios preparacion/GNOD-music-demonstrators/data_web_scarping_project'

# %%
df.to_csv('3_Spotipy_lab.csv', index=False)

# %%
df.keys()
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %% [markdown]
# -------------------------

# %%
df_num = df._get_numeric_data()
df_num.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.870   0.587    6    -6.117     1       0.0406      0.020900
# 1         0.905   0.492    2    -8.598     1       0.0595      0.014900
# 2         0.827   0.189    6    -9.370     0       0.0495      0.852000
# 3         0.502   0.912    1    -4.556     1       0.0564      0.000025
# 4         0.212   0.301    2   -12.505     1       0.0384      0.963000
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000003    0.0888   0.8140  122.939       191073               4
# 1          0.000038    0.3710   0.1420  110.017       177840               4
# 2          0.028000    0.1090   0.4850   88.349       192680               4
# 3          0.000173    0.1060   0.7200  116.761       301920               4
# 4          0.003300    0.1300   0.0798   84.025       177333               4

# %%
df_num
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.8700  0.5870    6    -6.117     1       0.0406      0.020900
# 1           0.9050  0.4920    2    -8.598     1       0.0595      0.014900
# 2           0.8270  0.1890    6    -9.370     0       0.0495      0.852000
# 3           0.5020  0.9120    1    -4.556     1       0.0564      0.000025
# 4           0.2120  0.3010    2   -12.505     1       0.0384      0.963000
# ...            ...     ...  ...       ...   ...          ...           ...
# 2544        0.2690  0.2380    9   -15.448     0       0.0315      0.972000
# 2545        0.5780  0.7930   10    -6.030     1       0.0484      0.002050
# 2546        0.1490  0.8590    8    -3.954     1       0.0480      0.109000
# 2547        0.4920  0.0499   11   -28.814     1       0.0484      0.753000
# 2548        0.0934  0.6070    2    -8.270     1       0.0389      0.000010
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000003    0.0888   0.8140  122.939       191073
# 1             0.000038    0.3710   0.1420  110.017       177840
# 2             0.028000    0.1090   0.4850   88.349       192680
# 3             0.000173    0.1060   0.7200  116.761       301920
# 4             0.003300    0.1300   0.0798   84.025       177333
# ...                ...       ...      ...      ...          ...
# 2544          0.749000    0.0999   0.0343   89.631       111800
# 2545          0.002080    0.0629   0.4530  123.023       208560
# 2546          0.001080    0.3290   0.4970   66.706       137680
# 2547          0.834000    0.1390   0.6310  101.366        90783
# 2548          0.572000    0.1370   0.1720  175.831       119347
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 2544               4
# 2545               4
# 2546               4
# 2547               3
# 2548               3
#
# [2549 rows x 13 columns]

# %%
col_names = df_num.columns

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(df_num)

# %%
X_prep_df = pd.DataFrame(X_prep, columns=col_names)

# %%
kmeans = KMeans(n_clusters=8, random_state=1234)
kmeans.fit(X_prep_df)
# Out:
# KMeans(random_state=1234)

# %%
kmeans.cluster_centers_
# Out:
# array([[-5.14680465e-01, -6.12710700e-01,  2.10162678e-01,
#         -6.34629586e-01, -3.61078690e-01, -2.48577711e-01,
#         -8.36687310e-02,  1.50862771e+00, -2.31863460e-02,
#         -6.60159385e-01, -1.90923677e-01,  6.68653824e+00,
#         -1.46006146e-01],
#        [ 7.62130153e-01,  6.27303970e-02, -6.96805236e-02,
#          2.24014229e-01, -8.76318473e-03,  3.60527648e+00,
#         -4.03344110e-02, -5.52985871e-01,  5.09152386e-02,
#          2.10059272e-01,  2.68514387e-01, -3.84853743e-01,
#          2.13281484e-01],
#        [-1.00076593e+00,  6.33305110e-01,  1.55573057e-04,
#          4.11299851e-01,  2.07649557e-01, -7.70194615e-02,
#         -6.43009928e-01,  5.52756113e-01, -9.83748435e-02,
#         -5.98161548e-01,  4.86133536e-01,  1.47948567e-01,
#         -8.28475224e-03],
#        [ 5.81219043e-01,  2.88863979e-01,  2.89761141e-01,
#          3.58713790e-01, -1.38196141e+00, -8.54506690e-02,
#         -3.74273944e-01, -3.68113477e-01, -2.42779998e-01,
#          5.87120479e-01, -1.50882664e-01, -1.63319307e-01,
#          2.06003878e-01],
#        [ 9.43365821e-02, -1.07377965e+00, -1.14085411e-01,
#         -3.45555523e-01,  7.89260655e-02, -2.93788926e-01,
#          1.25988726e+00, -4.41233583e-01, -2.74127864e-01,
#         -4.86553216e-01, -1.54679409e-01, -1.86141003e-01,
#         -3.93478645e-01],
#        [-2.10874085e-01,  5.78835018e-01,  5.34229759e-02,
#          3.89524216e-01,  2.03715225e-01, -6.59938953e-02,
#         -3.22371751e-01, -4.69270578e-01,  2.97919740e+00,
#          4.15393414e-02,  7.83057735e-02,  2.51727189e-02,
#          2.21220176e-01],
#        [ 6.66857958e-01,  4.31337978e-01, -1.45289303e-01,
#          3.90071371e-01,  7.23609205e-01, -2.12267518e-01,
#         -4.79113420e-01, -4.38235970e-01, -2.30764629e-01,
#          7.73128476e-01, -5.64507900e-02, -2.04372792e-01,
#          2.54854016e-01],
#        [-7.59547441e-01, -1.77214805e+00, -1.47055213e-02,
#         -2.27645936e+00, -3.07487732e-02, -3.01506340e-01,
#          1.71692252e+00,  1.49500462e+00, -3.24285445e-01,
#         -9.91522705e-01, -5.88744026e-01,  1.96412009e-02,
#         -6.41507887e-01]])

# %%
kmeans.inertia_
# Out:
# 18179.976918736

# %%
clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([6, 6, 4, ..., 2, 7, 2], dtype=int32)

# %%
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     33
# 1    115
# 2    555
# 3    443
# 4    356
# 5    162
# 6    631
# 7    254
# dtype: int64

# %%
X_df = pd.DataFrame(X_prep)
X_df['cluster'] = clusters
X_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.885459 -0.084680  0.227418  0.619074  0.723609 -0.396816 -0.857673
# 1  2.065114 -0.443532 -0.911461  0.178417  0.723609 -0.144823 -0.875043
# 2  1.664739 -1.588081  0.227418  0.041300 -1.381961 -0.278153  1.548288
# 3 -0.003494  1.142972 -1.196181  0.896328  0.723609 -0.186155 -0.918103
# 4 -1.492070 -1.165013 -0.911461 -0.515516  0.723609 -0.426149  1.869623
#
#           7         8         9        10        11        12  cluster
# 0 -0.711989 -0.598592  1.359750  0.118604 -0.446263  0.283751        6
# 1 -0.711893  0.905132 -1.237562 -0.311098 -0.512567  0.283751        6
# 2 -0.634478 -0.490954  0.088149 -1.031634 -0.438212  0.283751        4
# 3 -0.711518 -0.506940  0.996435 -0.086836  0.109128  0.283751        6
# 4 -0.702861 -0.379054 -1.477968 -1.175423 -0.515107  0.283751        4

# %%
X_df['cluster'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### <span style="color:#306998">Inertia</span>
# <span style="color:#306998">
# A way to find the centroids is to run the algorithm multiple times with different random initializations and keep the best solution. The number of random initializations is controlled by the n_init hyperparameter: by default, it is which means that the whole algorithm runs 10 times when we call fit(), and Scikit Learn keep the best solution. The inertia is the mean square distance between each instance and ist closest centroid. The KMeans class run the algorithm n_init times and keeps the model with the lowest inertia.
# </span>

# %%
# I want to iterate over a range of n_clusters and for every value, I want to return the inertia
def get_kmeans_inertia_varying_cluster_n(n_clusters):
    
    # setup the model
    kmeans = KMeans(n_clusters=n_clusters,
                    random_state=1234,
                    n_init=10,
                    #algorithm='elkan',
                   )
    # train the model
    kmeans.fit(X_prep_df)
    
    # return the resulting inertia
    return kmeans.inertia_

# Plot for a range of cluster numbers
import matplotlib.pyplot as plt

cluster_range = range(1,20)

plt.plot(cluster_range,
         [get_kmeans_inertia_varying_cluster_n(c_number) for c_number in cluster_range],
         marker="o",
         ms=10,
        )
plt.xlabel('Cluster Number')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %%
# I want to iterate over a range of mx_iter and for every value, I want to return the inertia
def get_kmeans_ineratia_varying_max_iter(max_iter):
    kmeans = KMeans(n_clusters=10,
                    random_state=1234,
                    n_init=10,
                    algorithm='elkan',
                    max_iter=max_iter,
                   )
    kmeans.fit(X_prep_df)

    return kmeans.inertia_

max_iter_list = [1, 5, 10, 20, 30, 40, 50, 100]

plt.plot(max_iter_list,
         [get_kmeans_ineratia_varying_max_iter(x) for x in max_iter_list],
        )
plt.xlabel('Max iter')
plt.ylabel('inertia')
# Out:
# Text(0, 0.5, 'inertia')

# %% [markdown]
# ### <span style="color:#306998">Silhouette coefficient</span>
# <span style="color:#306998">
# An instance's silhouette coefficient is equal to (b-a)/max(a,b), where a is the distance to the other instances in the same cluster and b is the mean nearest-cluster distance.
# The silhouette coefficient can vary between -1 and +1. A coefficient close to +1 means that the instance is well inside its own cluster and far from other clusters, while a coefficient close to 0 means that it is close to a cluster boundary, and finally a coefficient close to -1 means that the distance may have been assigned to the wrong cluster.
# </span>

# %%
from sklearn.metrics import silhouette_score

K = range(2, 20)

silhouettes = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                   random_state=1234)
    kmeans.fit(X_prep)
    silhouettes.append(silhouette_score(X_prep, kmeans.predict(X_prep)))

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(16,8))
plt.plot(K, silhouettes, 'bo-')
plt.xlabel('k (number of clusters)')
plt.ylabel('silhouette score')
# Out:
# Text(0, 0.5, 'silhouette score')

# %%
kmeans = KMeans(n_clusters=10,
             random_state=1234)

kmeans.fit(X_prep)

clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([8, 8, 7, ..., 5, 4, 5], dtype=int32)

# %%
clusters.shape
# Out:
# (2549,)

# %%
features_clustered = pd.DataFrame(X_prep, columns=col_names)

# %%
features_clustered['cluster_id'] = clusters

# %%
features_clustered.head()
# Out:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      1.885459 -0.084680  0.227418  0.619074  0.723609    -0.396816
# 1      2.065114 -0.443532 -0.911461  0.178417  0.723609    -0.144823
# 2      1.664739 -1.588081  0.227418  0.041300 -1.381961    -0.278153
# 3     -0.003494  1.142972 -1.196181  0.896328  0.723609    -0.186155
# 4     -1.492070 -1.165013 -0.911461 -0.515516  0.723609    -0.426149
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.018284         -0.548553  0.055849  0.225158  0.237386    -0.385967
# 1     -0.363223         -0.408699 -0.250851  0.627695 -0.177804    -0.174917
# 2     -0.466604          1.472001 -0.070527 -0.605979  0.136657     0.296581
# 3      0.761050          0.716521 -0.135036 -0.788576 -0.805746    -0.247282
# 4      1.757545          1.490320 -0.335079 -0.933117 -0.511447     0.029944
# 5     -0.744265         -0.523273 -0.092847 -0.389024  0.722784    -0.040648
# 6     -0.083669          1.508628 -0.023186 -0.660159 -0.190924     6.686538
# 7      1.263591         -0.510621 -0.284279 -0.509030 -0.160312    -0.197293
# 8     -0.433619         -0.412989 -0.233985  0.916310 -0.143334    -0.215697
# 9     -0.305889         -0.507900  3.069066  0.099705  0.065738    -0.017024
#
#    time_signature  cluster_id
# 0        0.210078           0
# 1        0.195876           1
# 2        0.111190           2
# 3       -6.083671           3
# 4       -0.258776           4
# 5        0.095772           5
# 6       -0.146006           6
# 7       -0.215143           7
# 8        0.264602           8
# 9        0.229724           9

# %%
# this contains my cluster centers
cluster_center_sub_df = cluster_centers_df[['danceability', 'loudness', 'cluster_id']]

features_clustered_sub_df= features_clustered[['danceability', 'loudness', 'cluster_id']]

# %%
cluster_center_sub_df
# Out:
#    danceability  loudness  cluster_id
# 0      0.748961  0.219903           0
# 1      0.653595  0.375777           1
# 2     -0.995143  0.188064           2
# 3     -0.925722 -1.411400           3
# 4     -0.655785 -2.205034           4
# 5     -0.722839  0.547086           5
# 6     -0.514680 -0.634630           6
# 7      0.100215 -0.337871           7
# 8      0.827736  0.373666           8
# 9     -0.152214  0.401093           9

# %%
features_clustered_sub_df
# Out:
#       danceability  loudness  cluster_id
# 0         1.885459  0.619074           8
# 1         2.065114  0.178417           8
# 2         1.664739  0.041300           7
# 3        -0.003494  0.896328           8
# 4        -1.492070 -0.515516           7
# ...            ...       ...         ...
# 2544     -1.199488 -1.038230           4
# 2545      0.386616  0.634527           8
# 2546     -1.815451  1.003251           5
# 2547     -0.054824 -3.412203           4
# 2548     -2.100847  0.236674           5
#
# [2549 rows x 3 columns]

# %%
import seaborn as sns

sns.scatterplot(data=features_clustered_sub_df,
               x='danceability',
               y='loudness',
               hue='cluster_id')

# plot centroids
sns.scatterplot(data=cluster_center_sub_df,
               x="danceability",
               y="loudness",
               hue='cluster_id',
                legend=False,
                # marker=u'8',
                marker='+',
                s=500,
               )
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='loudness'>

# %%
song = np.array([[-0.36992001,  0.42882697, -0.14838292,  0.17284094,  0.16457822,
        -0.03195258, -0.1271788 , -0.20547284,  3.02816589, -0.26732747,
         0.02835173,  0.09672491,  0.07415629]])

# %%
kmeans.predict(song)
# Out:
# array([9], dtype=int32)

# %% [markdown]
# -------------

# %%
hot_songs = pd.read_csv('Billboard_scraping.csv')

# %%
ls
# Out:
#  3_Spotipy_lab.csv         'C:\Users\Ron\Documents\Billboard_scraping.csv'
#  3_Spotipy_lab.ipynb        MVP_prototype.ipynb
#  Billboard_scraping.csv    'Web scraping | top 10 languages.ipynb'
#  Billboard_scraping.ipynb
